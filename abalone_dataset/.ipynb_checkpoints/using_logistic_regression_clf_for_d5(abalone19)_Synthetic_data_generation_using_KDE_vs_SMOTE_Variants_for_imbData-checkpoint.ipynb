# %%
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import f1_score
from imblearn.metrics import geometric_mean_score
from sklearn.metrics import cohen_kappa_score
from imblearn.over_sampling import SMOTE
from collections import Counter

# %%
with open ('abalone19.dat') as f:
     lines = [line.rstrip('\n')for line in f]

# %%
len(lines)
# Out:
# 4187

# %%
del lines[0:13]
data_string_list = []
for i in range(len(lines)):
    data_string_list.append(lines[i].split(','))
for j in range(len(data_string_list)):
    if data_string_list[j][0]=='M':
       data_string_list[j][0] = 1
    else:
        data_string_list[j][0] = 0

# %%
len(data_string_list)
# Out:
# 4174

# %%
labels=[]
for i in range(len(data_string_list)):
    if data_string_list[i][-1] == 'negative':
        labels.append(0)
    else:
        labels.append(1)
labels=np.array(labels)

# %%
np.unique(labels,return_counts=True)
# Out:
# (array([0, 1]), array([4142,   32], dtype=int64))

# %%
data_string_list=np.array(data_string_list)
data_string_list=data_string_list[:,:-1]

# %%
data_list=[]
for i in range(len(data_string_list)):
    row_list=[]
    for j in range(len(data_string_list[0])):
        f= float(data_string_list[i][j])
        row_list.append(f)
    data_list.append(row_list)
data = np.array(data_list)

# %%
data.shape
# Out:
# (4174, 8)

# %% [markdown]
# ### K-fold:

# %%
def get_folds(data,labels,k):
  np.random.seed(42)
  shuffle=np.random.permutation(len(data))
  data=data[shuffle]
  labels=labels[shuffle]

  block_length=int(len(data)/k)
  data_folds=[]
  label_folds=[]
  for i in range(k):
    if i==(k-1):
      data_fold=data[i*block_length:]
      data_folds.append(data_fold)
      label_fold=labels[i*block_length:]
      label_folds.append(label_fold)
    else:
      data_fold=data[i*block_length:block_length*(i+1)]
      data_folds.append(data_fold)
      label_fold=labels[i*block_length:block_length*(i+1)]
      label_folds.append(label_fold)
  return np.array(data_folds,dtype=object),np.array(label_folds,dtype=object)

# %%
def divide_data_into_k_folds(data,labels,k):
  data_folds_array,label_folds_array=get_folds(data,labels,k)
  all_data_folds_list=[]
  all_labels_folds_list=[]
  for i in range(k):
    data_fold_k=[np.concatenate(data_folds_array[np.where(np.array(list(range(k)))!=i)[0]]), data_folds_array[i]]
    all_data_folds_list.append(data_fold_k)

    label_fold_k=[np.concatenate(label_folds_array[np.where(np.array(list(range(k)))!=i)[0]]), label_folds_array[i]]
    all_labels_folds_list.append(label_fold_k)

  return all_data_folds_list, all_labels_folds_list

# %%
all_data_folds_list, all_labels_folds_list=divide_data_into_k_folds(data,labels,5)

# %%
X_train,X_test=all_data_folds_list[0][0],all_data_folds_list[0][1]

# %%
X_train.shape
# Out:
# (3340, 8)

# %%
y_train,y_test=all_labels_folds_list[0][0],all_labels_folds_list[0][1]

# %%
X_train_minority=[]
for i in np.where(y_train==1):
    a=X_train[i]
    X_train_minority.append(a)

# %%
X_train_minority_class=np.array(X_train_minority[0])

# %%
X_train_minority_class.shape
# Out:
# (28, 8)

# %%
X_train_majority=[]
for i in np.where(y_train==0):
    a=X_train[i]
    X_train_majority.append(a)

# %%
X_train_majority_class=np.array(X_train_majority[0])

# %%
X_train_majority_class.shape
# Out:
# (3312, 8)

# %% [markdown]
# ### Kernel Density Functon:

# %%
def k(H,x,d):
  H_inv = np.linalg.inv(H)
  x_tras=np.matrix.transpose(x)
  h= np.linalg.det(H)
  m=np.matmul(x_tras,H_inv)
  m1=np.matmul(m,x)
  e=np.exp(-0.5*m1)
  n=2*(np.pi)**(-d/2)
  v=n*(h)**(-1/2)*(e)
  return v

# %%
def density_gen(X, X_minority):
    density_list=[]
    for j in range(len(X)):
        s=0
        for i in range(len(X_minority)):
            xi=X_minority[i]
            dif=X[j]-xi
            s=s+k(np.identity(X_minority.shape[1]), dif, X_minority.shape[1])
        density_list.append(s/len(X_minority))
    return np.array(density_list)

# %%
unique_labels,counts=np.unique(y_train, return_counts=True)

# %%
def metropolis_hastings(target_density, X_minority, size=100):
    np.random.seed(43)
    burnin_size = 10000
    size += burnin_size
    x0 =X_minority[np.random.choice(list(range(len(X_train_minority_class))),1)]
    xt = x0
    samples = []
    for i in tqdm(range(size)):
        xt_candidate = np.array([np.random.multivariate_normal(xt[0], 0.2*np.eye(X_minority.shape[1]))])
        accept_odds = (target_density(xt_candidate,X_minority))/(target_density(xt,X_minority))
        if np.random.uniform(0, 1) < accept_odds:
            xt = xt_candidate
        samples.append(xt)
    samples = np.array(samples[burnin_size:])
    samples = np.reshape(samples, [samples.shape[0], X_minority.shape[1]])
    return samples

# %%
import smote_variants as sv

oversampler_SMOTE=sv.SMOTE()
oversampler_polynome_fit = sv.polynom_fit_SMOTE_star()
oversampler_ProWSyn= sv.ProWSyn()
oversampler_SMOTE_IPF= sv.SMOTE_IPF()
oversampler_Lee= sv.Lee()

# %%
oversampler_object_list = [oversampler_SMOTE,oversampler_polynome_fit,oversampler_ProWSyn, oversampler_Lee, metropolis_hastings]

# %%
oversampler_name_list = ['SMOTE','polynome_fit_SMOTE','ProWSyn', 'Lee', 'Metropolis_hastings']

# %%
def get_imb_oversampling(X_train,y_train,X_test,y_test,oversampler_index,classifier,visualize=True):
  ## MH is in the end of the list oversampler_object_list
  if oversampler_index!=len(oversampler_object_list)-1:
    X_samp, y_samp = oversampler_object_list[oversampler_index].sample(X_train, y_train)

  else:
    X_train_minority=[]
    for i in np.where(y_train==1):
      a=X_train[i]
      X_train_minority.append(a)

    X_train_majority=[]
    for i in np.where(y_train==0):
      a=X_train[i]
      X_train_majority.append(a)
    X_train_minority_class=np.array(X_train_minority[0])
    X_train_majority_class=np.array(X_train_majority[0])

    unique_labels,counts=np.unique(y_train, return_counts=True)

    synthetic_minority_data = metropolis_hastings(density_gen, X_train_minority_class, size=counts[0]-counts[1])
    balanced_minority=np.concatenate([X_train_minority_class, synthetic_minority_data])
    balanced_data=np.concatenate([X_train_majority_class,balanced_minority])
    balanced_labels_for_classification=np.concatenate([np.zeros(len(X_train_majority_class)),np.ones(len(balanced_minority))])
    X_samp=balanced_data
    y_samp=balanced_labels_for_classification

  classifier.fit(X_samp,y_samp)
  y_pred=classifier.predict(X_test)
  cm=confusion_matrix(y_test, y_pred)
  acc=accuracy_score(y_test, y_pred)
  b_acc=balanced_accuracy_score(y_test, y_pred)
  gm=geometric_mean_score(y_test, y_pred,average='micro')
  f1=f1_score(y_test, y_pred,average='micro')
  ck=cohen_kappa_score(y_test, y_pred)

  if visualize==True:
    scaler = StandardScaler()
    scaler.fit(X_samp)
    scaled_X_samp = scaler.transform(X_samp)
    pca = PCA(n_components =2)
    X_samp_pca=pca.fit_transform(scaled_X_samp)

    plt.figure(figsize=(8,6))
    color=["r","b"]
    color_counter=0
    for i in [-1,1]:
      plt.scatter(X_samp_pca[:,0][np.where(y_samp==i)],X_samp_pca[:,1][np.where(y_samp==i)], s=10, c=color[color_counter])
      color_counter=color_counter+1
    plt.legend(['Majority','Manority'],fontsize=10, loc='lower right')
    plt.xlabel("Principal Component 1",fontsize=12)
    plt.ylabel("Principlal Component 2 ",fontsize=12)
    plt.title("PCA plot of majority class + minority class using"+""+ oversampler_name_list[oversampler_index]+"technique",fontsize=14)


  return [cm, acc,b_acc,gm, f1, ck]

# %%
def calc_avg_performance(performance_index,results_all_folds):
  ## performance index takes the index of the performance measure foe which we want to average over folds
  ## results_all_folds are the results of a particular oversampler run over all folds recording all performance measures
  s=0
  for result in results_all_folds:
    s=s+result[performance_index]
  avg=s/len(results_all_folds)

  s=0
  for result in results_all_folds:
    s=s+(result[performance_index]-avg)**2
  std=np.sqrt(s/len(results_all_folds))
  return avg, std

# %%
clf=KNeighborsClassifier(n_neighbors=5)

# %%
perfromance_measures=['accuracy','balanced accuracy','g-mean','f1-score','cohen_kappa']
def get_results_all_folds(oversampler_index,classifier, visualize=False, get_detailed_results=False):

  results_all_folds=[]
  for i in range(len(all_data_folds_list)):
    X_train,X_test=all_data_folds_list[i][0],all_data_folds_list[i][1]
    y_train,y_test=all_labels_folds_list[i][0],all_labels_folds_list[i][1]
    results_single_fold=get_imb_oversampling(X_train,y_train,X_test,y_test,oversampler_index,clf,visualize=visualize)
    results_all_folds.append(results_single_fold)

  performance_summary_oversampler_classifer={}
  for performance_index in range(1,6):
    avg_std=calc_avg_performance(performance_index,results_all_folds)
    performance_summary_oversampler_classifer[perfromance_measures[performance_index-1]]=avg_std

  if get_detailed_results==True:
    return results_all_folds, performance_summary_oversampler_classifer
  else:
    return performance_summary_oversampler_classifer

# %%
get_results_all_folds(0,clf)
# Out:
# 2024-08-23 12:01:36,827:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2024-08-23 12:01:36,833:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:01:36,834:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:36,836:INFO:SMOTE: simplex sampling with n_dim 2
# 2024-08-23 12:01:36,881:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2024-08-23 12:01:36,882:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:01:36,883:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:36,884:INFO:SMOTE: simplex sampling with n_dim 2
# 2024-08-23 12:01:36,927:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2024-08-23 12:01:36,928:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:01:36,929:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:36,930:INFO:SMOTE: simplex sampling with n_dim 2
# 2024-08-23 12:01:36,966:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2024-08-23 12:01:36,966:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:01:36,966:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:36,966:INFO:SMOTE: simplex sampling with n_dim 2
# 2024-08-23 12:01:37,024:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2024-08-23 12:01:37,025:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:01:37,026:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:37,028:INFO:SMOTE: simplex sampling with n_dim 2
# {'accuracy': (0.8886174115600122, 0.014226845901854638),
#  'balanced accuracy': (0.6107531931409647, 0.06384534578184604),
#  'g-mean': (0.8886174115600122, 0.014226845901854638),
#  'f1-score': (0.8886174115600122, 0.014226845901854638),
#  'cohen_kappa': (0.037416664523162634, 0.03491627401468587)}

# %%
summary_performace_for_all_oversampling_algorithms_all_folds=[]
for i in range(len(oversampler_object_list)):
  summary_performace_for_all_oversampling_algorithms_all_folds.append(get_results_all_folds(i,clf))
# Out:
# 2024-08-23 12:01:37,076:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2024-08-23 12:01:37,077:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:01:37,078:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:37,079:INFO:SMOTE: simplex sampling with n_dim 2
# 2024-08-23 12:01:37,125:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2024-08-23 12:01:37,126:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:01:37,127:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:37,128:INFO:SMOTE: simplex sampling with n_dim 2
# 2024-08-23 12:01:37,175:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2024-08-23 12:01:37,176:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:01:37,177:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:37,178:INFO:SMOTE: simplex sampling with n_dim 2
# 2024-08-23 12:01:37,224:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2024-08-23 12:01:37,225:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:01:37,226:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:37,228:INFO:SMOTE: simplex sampling with n_dim 2
# 2024-08-23 12:01:37,272:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2024-08-23 12:01:37,273:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:01:37,273:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:37,275:INFO:SMOTE: simplex sampling with n_dim 2
# 2024-08-23 12:01:37,318:INFO:polynom_fit_SMOTE_star: Running sampling via ('polynom_fit_SMOTE_star', "{'proportion': 1.0, 'topology': 'star', 'random_state': None, 'class_name': 'polynom_fit_SMOTE_star'}")
# 2024-08-23 12:01:37,318:INFO:polynom_fit_SMOTE: Running sampling via ('polynom_fit_SMOTE', "{'proportion': 1.0, 'topology': 'star', 'random_state': None, 'class_name': 'polynom_fit_SMOTE'}")
# 2024-08-23 12:01:37,356:INFO:polynom_fit_SMOTE_star: Running sampling via ('polynom_fit_SMOTE_star', "{'proportion': 1.0, 'topology': 'star', 'random_state': None, 'class_name': 'polynom_fit_SMOTE_star'}")
# 2024-08-23 12:01:37,357:INFO:polynom_fit_SMOTE: Running sampling via ('polynom_fit_SMOTE', "{'proportion': 1.0, 'topology': 'star', 'random_state': None, 'class_name': 'polynom_fit_SMOTE'}")
# 2024-08-23 12:01:37,397:INFO:polynom_fit_SMOTE_star: Running sampling via ('polynom_fit_SMOTE_star', "{'proportion': 1.0, 'topology': 'star', 'random_state': None, 'class_name': 'polynom_fit_SMOTE_star'}")
# 2024-08-23 12:01:37,398:INFO:polynom_fit_SMOTE: Running sampling via ('polynom_fit_SMOTE', "{'proportion': 1.0, 'topology': 'star', 'random_state': None, 'class_name': 'polynom_fit_SMOTE'}")
# 2024-08-23 12:01:37,438:INFO:polynom_fit_SMOTE_star: Running sampling via ('polynom_fit_SMOTE_star', "{'proportion': 1.0, 'topology': 'star', 'random_state': None, 'class_name': 'polynom_fit_SMOTE_star'}")
# 2024-08-23 12:01:37,439:INFO:polynom_fit_SMOTE: Running sampling via ('polynom_fit_SMOTE', "{'proportion': 1.0, 'topology': 'star', 'random_state': None, 'class_name': 'polynom_fit_SMOTE'}")
# 2024-08-23 12:01:37,482:INFO:polynom_fit_SMOTE_star: Running sampling via ('polynom_fit_SMOTE_star', "{'proportion': 1.0, 'topology': 'star', 'random_state': None, 'class_name': 'polynom_fit_SMOTE_star'}")
# 2024-08-23 12:01:37,483:INFO:polynom_fit_SMOTE: Running sampling via ('polynom_fit_SMOTE', "{'proportion': 1.0, 'topology': 'star', 'random_state': None, 'class_name': 'polynom_fit_SMOTE'}")
# 2024-08-23 12:01:37,520:INFO:ProWSyn: Running sampling via ('ProWSyn', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'L': 5, 'theta': 1.0, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'ProWSyn'}")
# 2024-08-23 12:01:37,521:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:01:37,522:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:37,525:INFO:ProWSyn: simplex sampling with n_dim 2
# 2024-08-23 12:01:37,581:INFO:ProWSyn: Running sampling via ('ProWSyn', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'L': 5, 'theta': 1.0, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'ProWSyn'}")
# 2024-08-23 12:01:37,581:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:01:37,581:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:37,589:INFO:ProWSyn: simplex sampling with n_dim 2
# 2024-08-23 12:01:37,628:INFO:ProWSyn: Running sampling via ('ProWSyn', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'L': 5, 'theta': 1.0, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'ProWSyn'}")
# 2024-08-23 12:01:37,628:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:01:37,629:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:37,632:INFO:ProWSyn: simplex sampling with n_dim 2
# 2024-08-23 12:01:37,671:INFO:ProWSyn: Running sampling via ('ProWSyn', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'L': 5, 'theta': 1.0, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'ProWSyn'}")
# 2024-08-23 12:01:37,672:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:01:37,673:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:37,676:INFO:ProWSyn: simplex sampling with n_dim 2
# 2024-08-23 12:01:37,703:INFO:ProWSyn: Running sampling via ('ProWSyn', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'L': 5, 'theta': 1.0, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'ProWSyn'}")
# 2024-08-23 12:01:37,715:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:01:37,716:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:37,721:INFO:ProWSyn: simplex sampling with n_dim 2
# 2024-08-23 12:01:37,757:INFO:Lee: Running sampling via ('Lee', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'rejection_level': 0.5, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Lee'}")
# 2024-08-23 12:01:37,758:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:01:37,761:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:01:37,762:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:37,763:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:37,765:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:37,783:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:37,785:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:37,803:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:37,803:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:37,820:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:37,820:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:37,837:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:37,837:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:37,854:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:37,854:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:37,870:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:37,889:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:37,915:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:37,918:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:37,935:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:37,937:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:37,952:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:37,953:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:37,968:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:37,970:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:37,984:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:37,987:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,001:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,003:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,016:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,018:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,031:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,034:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,037:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,037:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,055:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,055:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,069:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,070:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,082:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,084:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,087:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,087:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,104:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,104:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,117:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,119:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,120:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,131:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,137:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,137:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,150:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,152:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,154:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,154:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,171:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,173:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,187:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,187:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,187:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,198:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,204:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,204:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,215:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,216:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,220:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,220:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,233:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,234:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,237:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,237:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,247:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,249:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,253:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,253:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,253:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,264:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,270:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,270:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,270:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,270:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,285:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,287:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,289:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,289:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,298:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,299:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,304:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,305:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,306:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,306:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,317:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,318:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,322:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,322:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,322:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,332:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,336:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,337:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,337:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,337:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,348:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,349:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,353:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,354:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,354:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,354:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,365:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,367:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,371:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,371:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,371:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,371:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,382:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,383:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,386:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,388:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,388:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,388:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,388:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,397:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,401:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,402:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,405:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,406:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,407:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,407:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,414:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,416:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,419:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,420:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,422:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,423:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,426:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,426:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,429:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,432:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,434:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,435:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,438:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,439:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,441:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,442:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,443:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,447:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,450:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,451:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,454:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,455:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,457:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,458:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,461:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,461:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,464:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,465:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,467:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,467:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,470:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,471:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,472:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,472:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,472:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,472:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,481:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,482:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,484:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,485:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,487:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,488:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,490:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,490:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,492:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,493:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,495:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,496:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,498:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,499:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,501:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,502:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,503:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,504:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,506:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,507:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,508:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,509:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,511:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,511:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,516:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,517:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,520:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,521:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,523:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,523:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,525:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,526:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,527:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,528:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,529:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,530:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,532:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,533:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,534:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,535:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,536:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,536:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,538:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,538:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,540:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,540:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,541:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,542:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,543:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,544:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,546:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,547:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,548:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,548:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,548:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,548:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,548:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,548:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,548:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,548:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,548:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,548:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,548:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,548:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,548:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,564:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,565:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,566:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,567:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,568:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,569:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,570:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,571:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,572:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,573:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,574:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,576:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,577:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,578:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,579:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,580:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,581:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,582:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,583:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,584:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,584:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,585:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,586:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,587:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,588:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,589:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,590:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,591:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,592:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,593:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,593:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,595:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,595:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,596:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,597:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,598:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,599:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,600:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,601:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,602:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,603:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,604:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,605:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,606:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,606:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,608:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,608:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,609:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,610:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,611:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,612:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,649:INFO:Lee: Running sampling via ('Lee', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'rejection_level': 0.5, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Lee'}")
# 2024-08-23 12:01:38,651:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:01:38,654:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:01:38,655:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,656:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,658:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,678:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,680:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,699:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,701:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,720:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,722:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,741:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,743:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,758:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,763:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,781:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,783:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,803:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,805:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,822:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,822:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,839:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,839:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,856:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,856:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,874:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,874:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,898:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,900:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,915:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,917:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,931:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,933:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,949:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,951:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,965:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,967:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:38,982:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:38,984:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,000:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,002:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,015:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,017:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,031:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,033:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,048:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,050:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,055:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,065:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,072:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,080:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,089:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,089:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,110:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,113:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,123:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,123:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,140:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,141:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,154:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,156:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,167:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,169:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,181:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,183:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,200:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,202:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,207:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,213:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,223:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,223:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,237:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,239:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,250:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,251:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,258:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,264:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,273:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,273:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,286:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,288:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,297:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,298:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,307:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,307:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,320:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,322:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,331:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,333:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,342:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,343:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,354:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,355:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,363:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,365:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,374:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,374:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,385:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,387:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,395:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,397:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,398:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,398:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,414:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,415:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,423:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,423:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,435:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,436:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,442:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,446:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,453:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,455:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,460:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,464:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,471:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,472:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,479:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,481:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,481:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,481:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,498:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,500:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,506:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,508:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,515:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,517:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,522:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,524:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,533:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,535:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,540:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,542:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,548:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,548:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,548:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,548:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,564:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,565:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,567:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,567:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,567:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,579:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,584:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,585:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,590:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,591:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,596:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,598:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,598:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,598:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,598:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,613:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,618:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,619:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,623:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,624:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,629:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,630:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,630:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,630:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,630:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,630:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,650:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,651:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,655:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,656:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,660:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,661:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,664:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,664:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,664:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,664:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,664:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,679:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,683:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,684:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,687:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,688:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,692:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,693:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,697:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,698:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,702:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,702:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,702:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,702:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,715:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,717:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,721:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,722:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,726:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,727:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,731:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,732:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,735:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,736:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,739:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,740:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,743:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,744:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,748:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,750:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,753:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,754:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,758:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,759:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,762:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,763:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,766:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,767:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,770:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,771:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,774:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,774:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,777:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,778:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,780:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,780:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,780:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,780:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,780:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,780:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,780:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,796:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,799:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,800:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,802:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,803:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,806:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,807:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,809:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:39,810:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:39,814:INFO:Lee: simplex sampling with n_dim 2
# ...
# 2024-08-23 12:01:42,451:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,452:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,454:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,455:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,457:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,458:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,460:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,460:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,462:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,463:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,465:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,466:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,468:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,469:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,471:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,472:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,473:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,474:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,476:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,477:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,479:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,480:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,482:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,483:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,484:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,485:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,487:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,488:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,490:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,492:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,496:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,498:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,500:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,501:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,503:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,504:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,506:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,507:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,509:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,509:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,511:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,512:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,514:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,515:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,517:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,518:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,520:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,520:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,522:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,523:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,525:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,526:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,527:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,528:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,529:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,530:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,532:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,532:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,534:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,535:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,536:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,537:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,539:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,539:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,541:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,542:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,544:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,545:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,546:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,547:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,549:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,549:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,551:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,552:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,554:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,554:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,556:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,557:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,558:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,559:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,560:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,560:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,562:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,562:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,564:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,565:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,566:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,567:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,569:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,570:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,571:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,572:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,573:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,574:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,576:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,577:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,578:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,579:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,581:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,581:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,583:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,584:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,585:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,586:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,588:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,589:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,591:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,591:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,593:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,594:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,596:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,597:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,598:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,599:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,600:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,601:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,603:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,604:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,605:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,605:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,607:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,607:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,608:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,609:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,610:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,610:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,612:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,612:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,613:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,614:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,616:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,617:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,619:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,619:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,619:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,619:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,619:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,627:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,628:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,629:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,630:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,631:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,632:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,633:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,634:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,634:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,635:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,636:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,637:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,638:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,639:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,640:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,641:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,641:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,642:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,643:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,645:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,646:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,648:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,649:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,650:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,651:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,652:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,652:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,654:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,654:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,655:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,658:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,661:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,664:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,667:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,676:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,683:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,684:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,685:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,686:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,690:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,691:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,692:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,693:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,695:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,696:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,698:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,701:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,704:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,705:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,706:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,708:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,709:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,710:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,712:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,713:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,715:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,715:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,717:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,718:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,719:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,719:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,720:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,721:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,722:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,722:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:01:42,723:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:01:42,724:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
#   0%|          | 0/13284 [00:00<?, ?it/s]
#   0%|          | 0/13286 [00:00<?, ?it/s]
#   0%|          | 0/13296 [00:00<?, ?it/s]
#   0%|          | 0/13294 [00:00<?, ?it/s]
#   0%|          | 0/13280 [00:00<?, ?it/s]

# %%
summary_performace_for_all_oversampling_algorithms_all_folds_list=np.array([[[round(i,3) for i in summary_performace_for_all_oversampling_algorithms_all_folds[oversampler_index][key]] for key in summary_performace_for_all_oversampling_algorithms_all_folds[0].keys()] for oversampler_index in range(len(oversampler_name_list))])

# %%
oversamplers_result_summary_list=[]
for i in range(summary_performace_for_all_oversampling_algorithms_all_folds_list.shape[0]):
  performance_results_summary_list=[]
  for j in range(summary_performace_for_all_oversampling_algorithms_all_folds_list.shape[1]):
    performance_results_summary_list.append(str(summary_performace_for_all_oversampling_algorithms_all_folds_list[i][j][0])+"\u00B1"+str(summary_performace_for_all_oversampling_algorithms_all_folds_list[i][j][1]))
  oversamplers_result_summary_list.append(performance_results_summary_list)
oversamplers_result_summary_list=np.array(oversamplers_result_summary_list)

# %%
performance_results_summary_list
# Out:
# ['0.992±0.003', '0.5±0.0', '0.992±0.003', '0.992±0.003', '-0.0±0.001']

# %%
oversamplers_result_summary_list
# Out:
# array([['0.887±0.012', '0.61±0.064', '0.887±0.012', '0.887±0.012',
#         '0.037±0.034'],
#        ['0.969±0.002', '0.499±0.022', '0.969±0.002', '0.969±0.002',
#         '0.002±0.025'],
#        ['0.872±0.02', '0.66±0.105', '0.872±0.02', '0.872±0.02',
#         '0.045±0.04'],
#        ['0.983±0.003', '0.527±0.044', '0.983±0.003', '0.983±0.003',
#         '0.053±0.079'],
#        ['0.992±0.003', '0.5±0.0', '0.992±0.003', '0.992±0.003',
#         '-0.0±0.001']], dtype='<U11')

# %%
df=pd.DataFrame(oversamplers_result_summary_list,columns=perfromance_measures,index=oversampler_name_list)

# %%
df
# Out:
#                         accuracy balanced accuracy       g-mean     f1-score  \
# SMOTE                0.887±0.012        0.61±0.064  0.887±0.012  0.887±0.012
# polynome_fit_SMOTE   0.969±0.002       0.499±0.022  0.969±0.002  0.969±0.002
# ProWSyn               0.872±0.02        0.66±0.105   0.872±0.02   0.872±0.02
# Lee                  0.983±0.003       0.527±0.044  0.983±0.003  0.983±0.003
# Metropolis_hastings  0.992±0.003           0.5±0.0  0.992±0.003  0.992±0.003
#
#                      cohen_kappa
# SMOTE                0.037±0.034
# polynome_fit_SMOTE   0.002±0.025
# ProWSyn               0.045±0.04
# Lee                  0.053±0.079
# Metropolis_hastings   -0.0±0.001

# %%
with pd.ExcelWriter('KNN_clf_result_for_d5.xlsx') as excel_writer:
  df.to_excel(excel_writer,sheet_name='sheet_1')

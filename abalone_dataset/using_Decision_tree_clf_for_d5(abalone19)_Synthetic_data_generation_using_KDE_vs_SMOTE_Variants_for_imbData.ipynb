# %%
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import f1_score
from imblearn.metrics import geometric_mean_score
from sklearn.metrics import cohen_kappa_score
from imblearn.over_sampling import SMOTE
from collections import Counter

# %%
with open ('abalone19.dat') as f:
     lines = [line.rstrip('\n')for line in f]

# %%
len(lines)
# Out:
# 4187

# %%
del lines[0:13]
data_string_list = []
for i in range(len(lines)):
    data_string_list.append(lines[i].split(','))
for i in range(len(data_string_list)):
    if data_string_list[i][0]=='M':
       data_string_list[i][0] = 1
    else:
        data_string_list[i][0] = 0

# %%
data_string_list[:1]
# Out:
# [[1,
#   ' 0.455',
#   ' 0.365',
#   ' 0.095',
#   ' 0.514',
#   ' 0.2245',
#   ' 0.101',
#   ' 0.15',
#   'negative']]

# %%
labels=[]
for i in range(len(data_string_list)):
    if data_string_list[i][-1] == 'negative':
        labels.append(0)
    else:
        labels.append(1)
labels=np.array(labels)

# %%
np.unique(labels)
# Out:
# array([0, 1])

# %%
data_string_list=np.array(data_string_list)
data_string_list=data_string_list[:,:-1]

# %%
data_list=[]
for i in range(len(data_string_list)):
    row_list=[]
    for j in range(len(data_string_list[0])):
        f= float(data_string_list[i][j])
        row_list.append(f)
    data_list.append(row_list)
data = np.array(data_list)

# %%
data.shape
# Out:
# (4174, 8)

# %% [markdown]
# ### K-fold:

# %%
def get_folds(data,labels,k):
  np.random.seed(42)
  shuffle=np.random.permutation(len(data))
  data=data[shuffle]
  labels=labels[shuffle]

  block_length=int(len(data)/k)
  data_folds=[]
  label_folds=[]
  for i in range(k):
    if i==(k-1):
      data_fold=data[i*block_length:]
      data_folds.append(data_fold)
      label_fold=labels[i*block_length:]
      label_folds.append(label_fold)
    else:
      data_fold=data[i*block_length:block_length*(i+1)]
      data_folds.append(data_fold)
      label_fold=labels[i*block_length:block_length*(i+1)]
      label_folds.append(label_fold)
  return np.array(data_folds,dtype=object),np.array(label_folds,dtype=object)

# %%
def divide_data_into_k_folds(data,labels,k):
  data_folds_array,label_folds_array=get_folds(data,labels,k)
  all_data_folds_list=[]
  all_labels_folds_list=[]
  for i in range(k):
    data_fold_k=[np.concatenate(data_folds_array[np.where(np.array(list(range(k)))!=i)[0]]), data_folds_array[i]]
    all_data_folds_list.append(data_fold_k)

    label_fold_k=[np.concatenate(label_folds_array[np.where(np.array(list(range(k)))!=i)[0]]), label_folds_array[i]]
    all_labels_folds_list.append(label_fold_k)

  return all_data_folds_list, all_labels_folds_list

# %%
all_data_folds_list, all_labels_folds_list=divide_data_into_k_folds(data,labels,5)

# %%
X_train,X_test=all_data_folds_list[0][0],all_data_folds_list[0][1]

# %%
X_train.shape
# Out:
# (3340, 8)

# %%
y_train,y_test=all_labels_folds_list[0][0],all_labels_folds_list[0][1]

# %%
X_train_minority=[]
for i in np.where(y_train==1):
    a=X_train[i]
    X_train_minority.append(a)

# %%
X_train_minority_class=np.array(X_train_minority[0])

# %%
X_train_minority_class.shape
# Out:
# (28, 8)

# %%
X_train_majority=[]
for i in np.where(y_train==0):
    a=X_train[i]
    X_train_majority.append(a)

# %%
X_train_majority_class=np.array(X_train_majority[0])

# %%
X_train_majority_class.shape
# Out:
# (3312, 8)

# %% [markdown]
# ### Kernel Density Functon:

# %%
def k(H,x,d):
  H_inv = np.linalg.inv(H)
  x_tras=np.matrix.transpose(x)
  h= np.linalg.det(H)
  m=np.matmul(x_tras,H_inv)
  m1=np.matmul(m,x)
  e=np.exp(-0.5*m1)
  n=2*(np.pi)**(-d/2)
  v=n*(h)**(-1/2)*(e)
  return v

# %%
def density_gen(X, X_minority):
    density_list=[]
    for j in range(len(X)):
        s=0
        for i in range(len(X_minority)):
            xi=X_minority[i]
            dif=X[j]-xi
            s=s+k(np.identity(X_minority.shape[1]), dif, X_minority.shape[1])
        density_list.append(s/len(X_minority))
    return np.array(density_list)

# %%
unique_labels,counts=np.unique(y_train, return_counts=True)

# %%
def metropolis_hastings(target_density, X_minority, size=100):
    np.random.seed(43)
    burnin_size = 10000
    size += burnin_size
    x0 =X_minority[np.random.choice(list(range(len(X_train_minority_class))),1)]
    xt = x0
    samples = []
    for i in tqdm(range(size)):
        xt_candidate = np.array([np.random.multivariate_normal(xt[0], 0.2*np.eye(X_minority.shape[1]))])
        accept_odds = (target_density(xt_candidate,X_minority))/(target_density(xt,X_minority))
        if np.random.uniform(0, 1) < accept_odds:
            xt = xt_candidate
        samples.append(xt)
    samples = np.array(samples[burnin_size:])
    samples = np.reshape(samples, [samples.shape[0], X_minority.shape[1]])
    return samples

# %%
import smote_variants as sv

oversampler_SMOTE=sv.SMOTE()
oversampler_polynome_fit = sv.polynom_fit_SMOTE_star()
oversampler_ProWSyn= sv.ProWSyn()
oversampler_SMOTE_IPF= sv.SMOTE_IPF()
oversampler_Lee= sv.Lee()

# %%
oversampler_object_list = [oversampler_SMOTE,oversampler_polynome_fit,oversampler_ProWSyn, oversampler_Lee, metropolis_hastings]

# %%
oversampler_name_list = ['SMOTE','polynome_fit_SMOTE','ProWSyn', 'Lee', 'Metropolis_hastings']

# %%
def get_imb_oversampling(X_train,y_train,X_test,y_test,oversampler_index,classifier,visualize=True):
  ## MH is in the end of the list oversampler_object_list
  if oversampler_index!=len(oversampler_object_list)-1:
    X_samp, y_samp = oversampler_object_list[oversampler_index].sample(X_train, y_train)

  else:
    X_train_minority=[]
    for i in np.where(y_train==1):
      a=X_train[i]
      X_train_minority.append(a)

    X_train_majority=[]
    for i in np.where(y_train==0):
      a=X_train[i]
      X_train_majority.append(a)
    X_train_minority_class=np.array(X_train_minority[0])
    X_train_majority_class=np.array(X_train_majority[0])

    unique_labels,counts=np.unique(y_train, return_counts=True)

    synthetic_minority_data = metropolis_hastings(density_gen, X_train_minority_class, size=counts[0]-counts[1])
    balanced_minority=np.concatenate([X_train_minority_class, synthetic_minority_data])
    balanced_data=np.concatenate([X_train_majority_class,balanced_minority])
    balanced_labels_for_classification=np.concatenate([np.zeros(len(X_train_majority_class)),np.ones(len(balanced_minority))])
    X_samp=balanced_data
    y_samp=balanced_labels_for_classification

  classifier.fit(X_samp,y_samp)
  y_pred=classifier.predict(X_test)
  cm=confusion_matrix(y_test, y_pred)
  acc=accuracy_score(y_test, y_pred)
  b_acc=balanced_accuracy_score(y_test, y_pred)
  gm=geometric_mean_score(y_test, y_pred,average='micro')
  f1=f1_score(y_test, y_pred,average='micro')
  ck=cohen_kappa_score(y_test, y_pred)

  if visualize==True:
    scaler = StandardScaler()
    scaler.fit(X_samp)
    scaled_X_samp = scaler.transform(X_samp)
    pca = PCA(n_components =2)
    X_samp_pca=pca.fit_transform(scaled_X_samp)

    plt.figure(figsize=(8,6))
    color=["r","b"]
    color_counter=0
    for i in [-1,1]:
      plt.scatter(X_samp_pca[:,0][np.where(y_samp==i)],X_samp_pca[:,1][np.where(y_samp==i)], s=10, c=color[color_counter])
      color_counter=color_counter+1
    plt.legend(['Majority','Manority'],fontsize=10, loc='lower right')
    plt.xlabel("Principal Component 1",fontsize=12)
    plt.ylabel("Principlal Component 2 ",fontsize=12)
    plt.title("PCA plot of majority class + minority class using"+""+ oversampler_name_list[oversampler_index]+"technique",fontsize=14)


  return [cm, acc,b_acc,gm, f1, ck]

# %%
def calc_avg_performance(performance_index,results_all_folds):
  ## performance index takes the index of the performance measure foe which we want to average over folds
  ## results_all_folds are the results of a particular oversampler run over all folds recording all performance measures
  s=0
  for result in results_all_folds:
    s=s+result[performance_index]
  avg=s/len(results_all_folds)

  s=0
  for result in results_all_folds:
    s=s+(result[performance_index]-avg)**2
  std=np.sqrt(s/len(results_all_folds))
  return avg, std

# %%
clf=DecisionTreeClassifier(random_state=0)

# %%
perfromance_measures=['accuracy','balanced accuracy','g-mean','f1-score','cohen_kappa']
def get_results_all_folds(oversampler_index,classifier, visualize=False, get_detailed_results=False):

  results_all_folds=[]
  for i in range(len(all_data_folds_list)):
    X_train,X_test=all_data_folds_list[i][0],all_data_folds_list[i][1]
    y_train,y_test=all_labels_folds_list[i][0],all_labels_folds_list[i][1]
    results_single_fold=get_imb_oversampling(X_train,y_train,X_test,y_test,oversampler_index,clf,visualize=visualize)
    results_all_folds.append(results_single_fold)

  performance_summary_oversampler_classifer={}
  for performance_index in range(1,6):
    avg_std=calc_avg_performance(performance_index,results_all_folds)
    performance_summary_oversampler_classifer[perfromance_measures[performance_index-1]]=avg_std

  if get_detailed_results==True:
    return results_all_folds, performance_summary_oversampler_classifer
  else:
    return performance_summary_oversampler_classifer

# %%
get_results_all_folds(0,clf)
# Out:
# 2024-08-23 12:23:42,092:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2024-08-23 12:23:42,092:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:23:42,092:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:42,092:INFO:SMOTE: simplex sampling with n_dim 2
# 2024-08-23 12:23:42,160:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2024-08-23 12:23:42,161:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:23:42,162:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:42,164:INFO:SMOTE: simplex sampling with n_dim 2
# 2024-08-23 12:23:42,217:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2024-08-23 12:23:42,218:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:23:42,219:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:42,221:INFO:SMOTE: simplex sampling with n_dim 2
# 2024-08-23 12:23:42,275:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2024-08-23 12:23:42,277:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:23:42,278:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:42,279:INFO:SMOTE: simplex sampling with n_dim 2
# 2024-08-23 12:23:42,336:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2024-08-23 12:23:42,338:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:23:42,338:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:42,338:INFO:SMOTE: simplex sampling with n_dim 2
# {'accuracy': (0.9516136971091385, 0.007068432644570924),
#  'balanced accuracy': (0.5003593180784623, 0.027601531518413366),
#  'g-mean': (0.9516136971091385, 0.007068432644570924),
#  'f1-score': (0.9516136971091385, 0.007068432644570924),
#  'cohen_kappa': (0.007290770096844645, 0.02080937405542804)}

# %%
summary_performace_for_all_oversampling_algorithms_all_folds=[]
for i in range(len(oversampler_object_list)):
  summary_performace_for_all_oversampling_algorithms_all_folds.append(get_results_all_folds(i,clf))
# Out:
# 2024-08-23 12:23:42,409:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2024-08-23 12:23:42,411:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:23:42,412:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:42,413:INFO:SMOTE: simplex sampling with n_dim 2
# 2024-08-23 12:23:42,471:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2024-08-23 12:23:42,471:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:23:42,471:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:42,471:INFO:SMOTE: simplex sampling with n_dim 2
# 2024-08-23 12:23:42,569:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2024-08-23 12:23:42,569:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:23:42,569:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:42,575:INFO:SMOTE: simplex sampling with n_dim 2
# 2024-08-23 12:23:42,631:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2024-08-23 12:23:42,633:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:23:42,634:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:42,635:INFO:SMOTE: simplex sampling with n_dim 2
# 2024-08-23 12:23:42,695:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2024-08-23 12:23:42,695:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:23:42,696:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:42,698:INFO:SMOTE: simplex sampling with n_dim 2
# 2024-08-23 12:23:42,757:INFO:polynom_fit_SMOTE_star: Running sampling via ('polynom_fit_SMOTE_star', "{'proportion': 1.0, 'topology': 'star', 'random_state': None, 'class_name': 'polynom_fit_SMOTE_star'}")
# 2024-08-23 12:23:42,758:INFO:polynom_fit_SMOTE: Running sampling via ('polynom_fit_SMOTE', "{'proportion': 1.0, 'topology': 'star', 'random_state': None, 'class_name': 'polynom_fit_SMOTE'}")
# 2024-08-23 12:23:42,776:INFO:polynom_fit_SMOTE_star: Running sampling via ('polynom_fit_SMOTE_star', "{'proportion': 1.0, 'topology': 'star', 'random_state': None, 'class_name': 'polynom_fit_SMOTE_star'}")
# 2024-08-23 12:23:42,776:INFO:polynom_fit_SMOTE: Running sampling via ('polynom_fit_SMOTE', "{'proportion': 1.0, 'topology': 'star', 'random_state': None, 'class_name': 'polynom_fit_SMOTE'}")
# 2024-08-23 12:23:42,793:INFO:polynom_fit_SMOTE_star: Running sampling via ('polynom_fit_SMOTE_star', "{'proportion': 1.0, 'topology': 'star', 'random_state': None, 'class_name': 'polynom_fit_SMOTE_star'}")
# 2024-08-23 12:23:42,793:INFO:polynom_fit_SMOTE: Running sampling via ('polynom_fit_SMOTE', "{'proportion': 1.0, 'topology': 'star', 'random_state': None, 'class_name': 'polynom_fit_SMOTE'}")
# 2024-08-23 12:23:42,821:INFO:polynom_fit_SMOTE_star: Running sampling via ('polynom_fit_SMOTE_star', "{'proportion': 1.0, 'topology': 'star', 'random_state': None, 'class_name': 'polynom_fit_SMOTE_star'}")
# 2024-08-23 12:23:42,823:INFO:polynom_fit_SMOTE: Running sampling via ('polynom_fit_SMOTE', "{'proportion': 1.0, 'topology': 'star', 'random_state': None, 'class_name': 'polynom_fit_SMOTE'}")
# 2024-08-23 12:23:42,844:INFO:polynom_fit_SMOTE_star: Running sampling via ('polynom_fit_SMOTE_star', "{'proportion': 1.0, 'topology': 'star', 'random_state': None, 'class_name': 'polynom_fit_SMOTE_star'}")
# 2024-08-23 12:23:42,844:INFO:polynom_fit_SMOTE: Running sampling via ('polynom_fit_SMOTE', "{'proportion': 1.0, 'topology': 'star', 'random_state': None, 'class_name': 'polynom_fit_SMOTE'}")
# 2024-08-23 12:23:42,860:INFO:ProWSyn: Running sampling via ('ProWSyn', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'L': 5, 'theta': 1.0, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'ProWSyn'}")
# 2024-08-23 12:23:42,860:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:23:42,871:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:42,875:INFO:ProWSyn: simplex sampling with n_dim 2
# 2024-08-23 12:23:42,907:INFO:ProWSyn: Running sampling via ('ProWSyn', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'L': 5, 'theta': 1.0, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'ProWSyn'}")
# 2024-08-23 12:23:42,908:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:23:42,909:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:42,914:INFO:ProWSyn: simplex sampling with n_dim 2
# 2024-08-23 12:23:42,951:INFO:ProWSyn: Running sampling via ('ProWSyn', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'L': 5, 'theta': 1.0, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'ProWSyn'}")
# 2024-08-23 12:23:42,952:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:23:42,953:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:42,956:INFO:ProWSyn: simplex sampling with n_dim 2
# 2024-08-23 12:23:42,992:INFO:ProWSyn: Running sampling via ('ProWSyn', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'L': 5, 'theta': 1.0, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'ProWSyn'}")
# 2024-08-23 12:23:42,993:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:23:42,994:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:42,997:INFO:ProWSyn: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,032:INFO:ProWSyn: Running sampling via ('ProWSyn', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'L': 5, 'theta': 1.0, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'ProWSyn'}")
# 2024-08-23 12:23:43,033:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:23:43,034:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,038:INFO:ProWSyn: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,074:INFO:Lee: Running sampling via ('Lee', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'rejection_level': 0.5, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Lee'}")
# 2024-08-23 12:23:43,075:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:23:43,078:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:23:43,079:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,081:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,083:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,094:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,104:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,123:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,125:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,143:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,144:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,189:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,199:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,223:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,224:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,241:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,241:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,254:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,254:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,271:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,271:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,288:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,288:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,304:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,304:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,337:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,338:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,354:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,354:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,370:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,371:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,387:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,388:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,404:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,404:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,421:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,421:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,437:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,437:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,454:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,454:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,471:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,471:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,488:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,488:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,504:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,504:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,504:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,504:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,521:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,521:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,537:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,537:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,537:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,554:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,554:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,554:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,571:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,571:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,571:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,587:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,587:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,587:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,604:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,604:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,604:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,604:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,621:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,621:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,621:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,637:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,637:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,637:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,652:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,654:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,654:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,654:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,671:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,671:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,671:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,671:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,686:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,687:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,687:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,687:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,687:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,703:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,704:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,704:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,721:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,721:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,721:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,737:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,737:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,737:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,753:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,755:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,757:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,757:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,772:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,774:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,774:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,774:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,789:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,790:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,794:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,794:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,807:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,808:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,813:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,815:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,823:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,826:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,831:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,833:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,837:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,839:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,841:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,841:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,854:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,856:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,859:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,861:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,864:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,866:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,866:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,875:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,881:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,883:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,886:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,887:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,890:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,891:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,894:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,895:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,898:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,899:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,903:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,904:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,906:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,906:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,906:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,906:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,906:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,921:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,925:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,926:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,928:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,929:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,932:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,933:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,935:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,937:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,940:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,941:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,943:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,945:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,947:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,948:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,951:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,953:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,957:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,960:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,963:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,964:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,966:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,967:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,970:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,971:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,973:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,974:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,976:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,977:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,979:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,979:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,981:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,982:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,984:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,985:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,987:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,988:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,990:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,991:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,993:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,993:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,995:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,996:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,998:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:43,998:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:43,998:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,004:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,007:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,008:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,010:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,011:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,012:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,013:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,015:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,016:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,018:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,019:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,020:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,021:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,023:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,024:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,025:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,026:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,028:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,029:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,032:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,033:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,036:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,038:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,040:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,042:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,044:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,045:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,048:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,049:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,058:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,061:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,070:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,072:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,074:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,076:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,078:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,080:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,081:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,083:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,084:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,085:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,086:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,087:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,090:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,094:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,096:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,098:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,099:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,100:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,101:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,103:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,105:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,106:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,108:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,108:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,108:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,108:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,108:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,108:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,120:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,121:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,122:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,123:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,124:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,125:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,125:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,126:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,127:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,128:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,129:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,130:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,131:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,132:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,134:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,135:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,136:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,137:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,138:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,139:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,140:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,141:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,142:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,143:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,144:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,145:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,147:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,147:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,149:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,149:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,171:INFO:Lee: Running sampling via ('Lee', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'rejection_level': 0.5, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Lee'}")
# 2024-08-23 12:23:44,173:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:23:44,176:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:23:44,176:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,177:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,179:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,199:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,200:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,220:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,222:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,247:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,250:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,268:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,270:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,288:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,290:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,307:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,307:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,332:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,334:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,355:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,356:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,377:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,377:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,392:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,404:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,422:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,422:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,439:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,439:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,472:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,474:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,492:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,492:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,512:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,512:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,527:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,527:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,553:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,556:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,576:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,578:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,595:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,598:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,613:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,613:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,637:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,640:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,658:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,660:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,673:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,675:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,688:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,692:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,704:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,704:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,723:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,726:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,738:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,740:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,756:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,757:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,770:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,772:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,779:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,787:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,794:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,794:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,809:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,809:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,827:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,827:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,845:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,845:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,860:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,860:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,874:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,876:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,886:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,888:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,898:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,898:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,916:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,918:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,928:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,929:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,938:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,939:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,939:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,939:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,960:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,961:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,970:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,972:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,980:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,980:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:44,994:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:44,996:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,003:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,007:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,015:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,017:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,023:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,023:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,039:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,041:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,043:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,043:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,061:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,063:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,072:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,075:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,083:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,084:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,089:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,089:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,102:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,104:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,111:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,112:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,120:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,122:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,129:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,130:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,136:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,138:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,139:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,139:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,154:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,155:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,161:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,163:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,171:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,173:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,179:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,181:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,186:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,187:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,193:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,193:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,203:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,204:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,210:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,211:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,216:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,218:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,225:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,228:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,233:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,234:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,239:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,240:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,245:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,247:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,253:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,255:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,260:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,262:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,267:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,268:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,272:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,274:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,278:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,278:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,286:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,288:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,292:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,293:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,297:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,299:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,303:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,304:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,307:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,309:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,311:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,311:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,322:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,323:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,327:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,329:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,333:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,334:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,339:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,340:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,344:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,345:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,348:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,348:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,356:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,357:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,361:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,362:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,366:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,367:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,371:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,372:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,375:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,377:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,380:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,382:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,385:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,386:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,389:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,390:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,393:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,393:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,393:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,393:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,404:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,406:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,408:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,409:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,413:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,414:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,417:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,418:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,421:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,422:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,424:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,425:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,428:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,429:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,432:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,433:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,435:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,436:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,439:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,440:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,442:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,444:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,445:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,452:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,455:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:45,456:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:45,460:INFO:Lee: simplex sampling with n_dim 2
# ...
# 2024-08-23 12:23:48,135:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,136:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,138:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,139:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,141:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,142:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,144:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,145:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,147:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,148:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,150:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,151:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,152:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,153:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,155:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,156:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,158:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,159:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,161:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,161:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,164:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,165:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,167:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,168:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,170:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,171:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,173:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,174:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,176:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,177:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,179:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,180:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,181:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,182:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,184:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,185:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,187:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,188:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,189:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,190:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,192:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,193:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,195:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,196:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,198:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,199:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,201:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,202:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,203:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,204:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,207:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,208:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,210:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,210:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,212:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,213:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,214:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,215:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,217:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,217:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,219:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,220:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,222:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,223:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,225:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,226:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,228:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,229:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,229:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,229:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,237:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,240:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,242:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,244:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,245:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,246:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,248:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,249:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,250:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,251:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,253:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,254:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,256:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,257:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,258:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,259:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,261:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,262:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,263:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,264:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,266:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,266:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,266:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,266:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,266:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,266:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,266:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,266:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,266:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,266:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,266:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,266:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,280:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,280:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,282:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,283:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,284:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,285:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,287:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,287:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,289:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,289:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,291:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,292:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,293:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,294:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,296:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,297:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,298:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,300:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,301:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,302:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,303:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,304:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,305:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,306:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,307:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,308:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,310:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,310:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,312:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,313:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,314:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,315:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,317:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,318:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,319:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,320:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,322:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,323:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,324:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,325:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,326:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,327:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,329:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,329:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,331:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,331:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,332:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,333:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,334:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,334:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,336:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,336:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,337:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,338:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,339:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,340:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,341:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,343:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,344:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,345:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,346:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,346:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,348:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,348:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,350:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,351:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,351:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,352:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,354:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,355:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,355:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,355:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,355:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,355:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,355:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,355:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,366:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,367:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,368:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,369:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,369:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,370:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,371:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,372:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,373:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,374:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,374:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,375:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,376:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,377:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,378:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,378:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,379:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,380:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,381:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,382:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,383:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,384:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,385:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,386:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:23:48,387:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:23:48,388:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
#   0%|          | 0/13284 [00:00<?, ?it/s]
#   0%|          | 0/13286 [00:00<?, ?it/s]
#   0%|          | 0/13296 [00:00<?, ?it/s]
#   0%|          | 0/13294 [00:00<?, ?it/s]
#   0%|          | 0/13280 [00:00<?, ?it/s]

# %%
summary_performace_for_all_oversampling_algorithms_all_folds_list=np.array([[[round(i,3) for i in summary_performace_for_all_oversampling_algorithms_all_folds[oversampler_index][key]] for key in summary_performace_for_all_oversampling_algorithms_all_folds[0].keys()] for oversampler_index in range(len(oversampler_name_list))])

# %%
oversamplers_result_summary_list=[]
for i in range(summary_performace_for_all_oversampling_algorithms_all_folds_list.shape[0]):
  performance_results_summary_list=[]
  for j in range(summary_performace_for_all_oversampling_algorithms_all_folds_list.shape[1]):
    performance_results_summary_list.append(str(summary_performace_for_all_oversampling_algorithms_all_folds_list[i][j][0])+"\u00B1"+str(summary_performace_for_all_oversampling_algorithms_all_folds_list[i][j][1]))
  oversamplers_result_summary_list.append(performance_results_summary_list)
oversamplers_result_summary_list=np.array(oversamplers_result_summary_list)

# %%
performance_results_summary_list
# Out:
# ['0.981±0.002', '0.519±0.05', '0.981±0.002', '0.981±0.002', '0.016±0.051']

# %%
oversamplers_result_summary_list
# Out:
# array([['0.953±0.004', '0.555±0.148', '0.953±0.004', '0.953±0.004',
#         '0.013±0.052'],
#        ['0.982±0.003', '0.495±0.001', '0.982±0.003', '0.982±0.003',
#         '-0.008±0.002'],
#        ['0.94±0.006', '0.517±0.065', '0.94±0.006', '0.94±0.006',
#         '0.016±0.037'],
#        ['0.982±0.005', '0.57±0.148', '0.982±0.005', '0.982±0.005',
#         '0.047±0.11'],
#        ['0.981±0.002', '0.519±0.05', '0.981±0.002', '0.981±0.002',
#         '0.016±0.051']], dtype='<U12')

# %%
df=pd.DataFrame(oversamplers_result_summary_list,columns=perfromance_measures,index=oversampler_name_list)

# %%
df
# Out:
#                         accuracy balanced accuracy       g-mean     f1-score  \
# SMOTE                0.953±0.004       0.555±0.148  0.953±0.004  0.953±0.004
# polynome_fit_SMOTE   0.982±0.003       0.495±0.001  0.982±0.003  0.982±0.003
# ProWSyn               0.94±0.006       0.517±0.065   0.94±0.006   0.94±0.006
# Lee                  0.982±0.005        0.57±0.148  0.982±0.005  0.982±0.005
# Metropolis_hastings  0.981±0.002        0.519±0.05  0.981±0.002  0.981±0.002
#
#                       cohen_kappa
# SMOTE                 0.013±0.052
# polynome_fit_SMOTE   -0.008±0.002
# ProWSyn               0.016±0.037
# Lee                    0.047±0.11
# Metropolis_hastings   0.016±0.051

# %%
with pd.ExcelWriter('Decision_tree_clf_result_for_d5.xlsx') as excel_writer:
  df.to_excel(excel_writer,sheet_name='sheet_1')

# %%
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import f1_score
from imblearn.metrics import geometric_mean_score
from sklearn.metrics import cohen_kappa_score
from imblearn.over_sampling import SMOTE
from collections import Counter

# %%
with open ('abalone19.dat') as f:
     lines = [line.rstrip('\n')for line in f]

# %%
len(lines)
# Out:
# 4187

# %%
del lines[0:13]
data_string_list = []
for i in range(len(lines)):
    data_string_list.append(lines[i].split(','))
for j in range(len(data_string_list)):
    if data_string_list[j][0]=='M':
       data_string_list[j][0] = 1
    else:
        data_string_list[j][0] = 0

# %%
len(data_string_list)
# Out:
# 4174

# %%
labels=[]
for i in range(len(data_string_list)):
    if data_string_list[i][-1] == 'negative':
        labels.append(0)
    else:
        labels.append(1)
labels=np.array(labels)

# %%
np.unique(labels,return_counts=True)
# Out:
# (array([0, 1]), array([4142,   32], dtype=int64))

# %%
data_string_list=np.array(data_string_list)
data_string_list=data_string_list[:,:-1]

# %%
data_list=[]
for i in range(len(data_string_list)):
    row_list=[]
    for j in range(len(data_string_list[0])):
        f= float(data_string_list[i][j])
        row_list.append(f)
    data_list.append(row_list)
data = np.array(data_list)

# %%
data.shape
# Out:
# (4174, 8)

# %% [markdown]
# ### K-fold:

# %%
def get_folds(data,labels,k):
  np.random.seed(42)
  shuffle=np.random.permutation(len(data))
  data=data[shuffle]
  labels=labels[shuffle]

  block_length=int(len(data)/k)
  data_folds=[]
  label_folds=[]
  for i in range(k):
    if i==(k-1):
      data_fold=data[i*block_length:]
      data_folds.append(data_fold)
      label_fold=labels[i*block_length:]
      label_folds.append(label_fold)
    else:
      data_fold=data[i*block_length:block_length*(i+1)]
      data_folds.append(data_fold)
      label_fold=labels[i*block_length:block_length*(i+1)]
      label_folds.append(label_fold)
  return np.array(data_folds,dtype=object),np.array(label_folds,dtype=object)

# %%
def divide_data_into_k_folds(data,labels,k):
  data_folds_array,label_folds_array=get_folds(data,labels,k)
  all_data_folds_list=[]
  all_labels_folds_list=[]
  for i in range(k):
    data_fold_k=[np.concatenate(data_folds_array[np.where(np.array(list(range(k)))!=i)[0]]), data_folds_array[i]]
    all_data_folds_list.append(data_fold_k)

    label_fold_k=[np.concatenate(label_folds_array[np.where(np.array(list(range(k)))!=i)[0]]), label_folds_array[i]]
    all_labels_folds_list.append(label_fold_k)

  return all_data_folds_list, all_labels_folds_list

# %%
all_data_folds_list, all_labels_folds_list=divide_data_into_k_folds(data,labels,5)

# %%
X_train,X_test=all_data_folds_list[0][0],all_data_folds_list[0][1]

# %%
X_train.shape
# Out:
# (3340, 8)

# %%
y_train,y_test=all_labels_folds_list[0][0],all_labels_folds_list[0][1]

# %%
X_train_minority=[]
for i in np.where(y_train==1):
    a=X_train[i]
    X_train_minority.append(a)

# %%
X_train_minority_class=np.array(X_train_minority[0])

# %%
X_train_minority_class.shape
# Out:
# (28, 8)

# %%
X_train_majority=[]
for i in np.where(y_train==0):
    a=X_train[i]
    X_train_majority.append(a)

# %%
X_train_majority_class=np.array(X_train_majority[0])

# %%
X_train_majority_class.shape
# Out:
# (3312, 8)

# %% [markdown]
# ### Kernel Density Functon:

# %%
def k(H,x,d):
  H_inv = np.linalg.inv(H)
  x_tras=np.matrix.transpose(x)
  h= np.linalg.det(H)
  m=np.matmul(x_tras,H_inv)
  m1=np.matmul(m,x)
  e=np.exp(-0.5*m1)
  n=2*(np.pi)**(-d/2)
  v=n*(h)**(-1/2)*(e)
  return v

# %%
def density_gen(X, X_minority):
    density_list=[]
    for j in range(len(X)):
        s=0
        for i in range(len(X_minority)):
            xi=X_minority[i]
            dif=X[j]-xi
            s=s+k(np.identity(X_minority.shape[1]), dif, X_minority.shape[1])
        density_list.append(s/len(X_minority))
    return np.array(density_list)

# %%
unique_labels,counts=np.unique(y_train, return_counts=True)

# %%
def metropolis_hastings(target_density, X_minority, size=100):
    np.random.seed(43)
    burnin_size = 10000
    size += burnin_size
    x0 =X_minority[np.random.choice(list(range(len(X_train_minority_class))),1)]
    xt = x0
    samples = []
    for i in tqdm(range(size)):
        xt_candidate = np.array([np.random.multivariate_normal(xt[0], 0.2*np.eye(X_minority.shape[1]))])
        accept_odds = (target_density(xt_candidate,X_minority))/(target_density(xt,X_minority))
        if np.random.uniform(0, 1) < accept_odds:
            xt = xt_candidate
        samples.append(xt)
    samples = np.array(samples[burnin_size:])
    samples = np.reshape(samples, [samples.shape[0], X_minority.shape[1]])
    return samples

# %%
import smote_variants as sv

oversampler_SMOTE=sv.SMOTE()
oversampler_polynome_fit = sv.polynom_fit_SMOTE_star()
oversampler_ProWSyn= sv.ProWSyn()
oversampler_SMOTE_IPF= sv.SMOTE_IPF()
oversampler_Lee= sv.Lee()

# %%
oversampler_object_list = [oversampler_SMOTE,oversampler_polynome_fit,oversampler_ProWSyn, oversampler_Lee, metropolis_hastings]

# %%
oversampler_name_list = ['SMOTE','polynome_fit_SMOTE','ProWSyn', 'Lee', 'Metropolis_hastings']

# %%
def get_imb_oversampling(X_train,y_train,X_test,y_test,oversampler_index,classifier,visualize=True):
  ## MH is in the end of the list oversampler_object_list
  if oversampler_index!=len(oversampler_object_list)-1:
    X_samp, y_samp = oversampler_object_list[oversampler_index].sample(X_train, y_train)

  else:
    X_train_minority=[]
    for i in np.where(y_train==1):
      a=X_train[i]
      X_train_minority.append(a)

    X_train_majority=[]
    for i in np.where(y_train==0):
      a=X_train[i]
      X_train_majority.append(a)
    X_train_minority_class=np.array(X_train_minority[0])
    X_train_majority_class=np.array(X_train_majority[0])

    unique_labels,counts=np.unique(y_train, return_counts=True)

    synthetic_minority_data = metropolis_hastings(density_gen, X_train_minority_class, size=counts[0]-counts[1])
    balanced_minority=np.concatenate([X_train_minority_class, synthetic_minority_data])
    balanced_data=np.concatenate([X_train_majority_class,balanced_minority])
    balanced_labels_for_classification=np.concatenate([np.zeros(len(X_train_majority_class)),np.ones(len(balanced_minority))])
    X_samp=balanced_data
    y_samp=balanced_labels_for_classification

  classifier.fit(X_samp,y_samp)
  y_pred=classifier.predict(X_test)
  cm=confusion_matrix(y_test, y_pred)
  acc=accuracy_score(y_test, y_pred)
  b_acc=balanced_accuracy_score(y_test, y_pred)
  gm=geometric_mean_score(y_test, y_pred,average='micro')
  f1=f1_score(y_test, y_pred,average='micro')
  ck=cohen_kappa_score(y_test, y_pred)

  if visualize==True:
    scaler = StandardScaler()
    scaler.fit(X_samp)
    scaled_X_samp = scaler.transform(X_samp)
    pca = PCA(n_components =2)
    X_samp_pca=pca.fit_transform(scaled_X_samp)

    plt.figure(figsize=(8,6))
    color=["r","b"]
    color_counter=0
    for i in [-1,1]:
      plt.scatter(X_samp_pca[:,0][np.where(y_samp==i)],X_samp_pca[:,1][np.where(y_samp==i)], s=10, c=color[color_counter])
      color_counter=color_counter+1
    plt.legend(['Majority','Manority'],fontsize=10, loc='lower right')
    plt.xlabel("Principal Component 1",fontsize=12)
    plt.ylabel("Principlal Component 2 ",fontsize=12)
    plt.title("PCA plot of majority class + minority class using"+""+ oversampler_name_list[oversampler_index]+"technique",fontsize=14)


  return [cm, acc,b_acc,gm, f1, ck]

# %%
def calc_avg_performance(performance_index,results_all_folds):
  ## performance index takes the index of the performance measure foe which we want to average over folds
  ## results_all_folds are the results of a particular oversampler run over all folds recording all performance measures
  s=0
  for result in results_all_folds:
    s=s+result[performance_index]
  avg=s/len(results_all_folds)

  s=0
  for result in results_all_folds:
    s=s+(result[performance_index]-avg)**2
  std=np.sqrt(s/len(results_all_folds))
  return avg, std

# %%
clf = LogisticRegression(random_state=0)

# %%
perfromance_measures=['accuracy','balanced accuracy','g-mean','f1-score','cohen_kappa']
def get_results_all_folds(oversampler_index,classifier, visualize=False, get_detailed_results=False):

  results_all_folds=[]
  for i in range(len(all_data_folds_list)):
    X_train,X_test=all_data_folds_list[i][0],all_data_folds_list[i][1]
    y_train,y_test=all_labels_folds_list[i][0],all_labels_folds_list[i][1]
    results_single_fold=get_imb_oversampling(X_train,y_train,X_test,y_test,oversampler_index,clf,visualize=visualize)
    results_all_folds.append(results_single_fold)

  performance_summary_oversampler_classifer={}
  for performance_index in range(1,6):
    avg_std=calc_avg_performance(performance_index,results_all_folds)
    performance_summary_oversampler_classifer[perfromance_measures[performance_index-1]]=avg_std

  if get_detailed_results==True:
    return results_all_folds, performance_summary_oversampler_classifer
  else:
    return performance_summary_oversampler_classifer

# %%
get_results_all_folds(0,clf)
# Out:
# 2024-08-23 12:35:28,931:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2024-08-23 12:35:28,937:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:35:28,938:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:28,939:INFO:SMOTE: simplex sampling with n_dim 2
# 2024-08-23 12:35:28,973:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2024-08-23 12:35:28,974:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:35:28,975:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:28,976:INFO:SMOTE: simplex sampling with n_dim 2
# 2024-08-23 12:35:28,993:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2024-08-23 12:35:28,993:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:35:28,993:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,004:INFO:SMOTE: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,024:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2024-08-23 12:35:29,025:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:35:29,026:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,026:INFO:SMOTE: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,044:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2024-08-23 12:35:29,044:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:35:29,044:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,053:INFO:SMOTE: simplex sampling with n_dim 2
# {'accuracy': (0.8088185299016157, 0.009193862152703824),
#  'balanced accuracy': (0.7845287657369079, 0.10434251751731508),
#  'g-mean': (0.8088185299016157, 0.009193862152703824),
#  'f1-score': (0.8088185299016157, 0.009193862152703824),
#  'cohen_kappa': (0.04535811735750746, 0.026459803460266235)}

# %%
summary_performace_for_all_oversampling_algorithms_all_folds=[]
for i in range(len(oversampler_object_list)):
  summary_performace_for_all_oversampling_algorithms_all_folds.append(get_results_all_folds(i,clf))
# Out:
# 2024-08-23 12:35:29,080:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2024-08-23 12:35:29,087:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:35:29,089:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,091:INFO:SMOTE: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,115:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2024-08-23 12:35:29,118:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:35:29,120:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,122:INFO:SMOTE: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,142:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2024-08-23 12:35:29,142:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:35:29,142:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,142:INFO:SMOTE: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,175:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2024-08-23 12:35:29,177:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:35:29,177:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,177:INFO:SMOTE: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,205:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2024-08-23 12:35:29,206:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:35:29,207:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,208:INFO:SMOTE: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,228:INFO:polynom_fit_SMOTE_star: Running sampling via ('polynom_fit_SMOTE_star', "{'proportion': 1.0, 'topology': 'star', 'random_state': None, 'class_name': 'polynom_fit_SMOTE_star'}")
# 2024-08-23 12:35:29,228:INFO:polynom_fit_SMOTE: Running sampling via ('polynom_fit_SMOTE', "{'proportion': 1.0, 'topology': 'star', 'random_state': None, 'class_name': 'polynom_fit_SMOTE'}")
# 2024-08-23 12:35:29,243:INFO:polynom_fit_SMOTE_star: Running sampling via ('polynom_fit_SMOTE_star', "{'proportion': 1.0, 'topology': 'star', 'random_state': None, 'class_name': 'polynom_fit_SMOTE_star'}")
# 2024-08-23 12:35:29,243:INFO:polynom_fit_SMOTE: Running sampling via ('polynom_fit_SMOTE', "{'proportion': 1.0, 'topology': 'star', 'random_state': None, 'class_name': 'polynom_fit_SMOTE'}")
# 2024-08-23 12:35:29,273:INFO:polynom_fit_SMOTE_star: Running sampling via ('polynom_fit_SMOTE_star', "{'proportion': 1.0, 'topology': 'star', 'random_state': None, 'class_name': 'polynom_fit_SMOTE_star'}")
# 2024-08-23 12:35:29,273:INFO:polynom_fit_SMOTE: Running sampling via ('polynom_fit_SMOTE', "{'proportion': 1.0, 'topology': 'star', 'random_state': None, 'class_name': 'polynom_fit_SMOTE'}")
# 2024-08-23 12:35:29,293:INFO:polynom_fit_SMOTE_star: Running sampling via ('polynom_fit_SMOTE_star', "{'proportion': 1.0, 'topology': 'star', 'random_state': None, 'class_name': 'polynom_fit_SMOTE_star'}")
# 2024-08-23 12:35:29,293:INFO:polynom_fit_SMOTE: Running sampling via ('polynom_fit_SMOTE', "{'proportion': 1.0, 'topology': 'star', 'random_state': None, 'class_name': 'polynom_fit_SMOTE'}")
# 2024-08-23 12:35:29,311:INFO:polynom_fit_SMOTE_star: Running sampling via ('polynom_fit_SMOTE_star', "{'proportion': 1.0, 'topology': 'star', 'random_state': None, 'class_name': 'polynom_fit_SMOTE_star'}")
# 2024-08-23 12:35:29,311:INFO:polynom_fit_SMOTE: Running sampling via ('polynom_fit_SMOTE', "{'proportion': 1.0, 'topology': 'star', 'random_state': None, 'class_name': 'polynom_fit_SMOTE'}")
# 2024-08-23 12:35:29,335:INFO:ProWSyn: Running sampling via ('ProWSyn', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'L': 5, 'theta': 1.0, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'ProWSyn'}")
# 2024-08-23 12:35:29,336:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:35:29,337:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,341:INFO:ProWSyn: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,356:INFO:ProWSyn: Running sampling via ('ProWSyn', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'L': 5, 'theta': 1.0, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'ProWSyn'}")
# 2024-08-23 12:35:29,357:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:35:29,359:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,360:INFO:ProWSyn: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,378:INFO:ProWSyn: Running sampling via ('ProWSyn', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'L': 5, 'theta': 1.0, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'ProWSyn'}")
# 2024-08-23 12:35:29,378:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:35:29,378:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,388:INFO:ProWSyn: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,396:INFO:ProWSyn: Running sampling via ('ProWSyn', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'L': 5, 'theta': 1.0, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'ProWSyn'}")
# 2024-08-23 12:35:29,403:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:35:29,404:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,408:INFO:ProWSyn: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,425:INFO:ProWSyn: Running sampling via ('ProWSyn', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'L': 5, 'theta': 1.0, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'ProWSyn'}")
# 2024-08-23 12:35:29,426:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:35:29,427:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,428:INFO:ProWSyn: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,447:INFO:Lee: Running sampling via ('Lee', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'rejection_level': 0.5, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Lee'}")
# 2024-08-23 12:35:29,453:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:35:29,458:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:35:29,459:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,460:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,462:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,477:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,486:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,503:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,505:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,524:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,526:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,544:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,544:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,560:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,571:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,590:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,592:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,607:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,609:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,628:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,629:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,644:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,644:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,660:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,660:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,676:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,676:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,693:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,693:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,710:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,711:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,754:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,758:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,771:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,771:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,787:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,787:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,809:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,811:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,823:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,825:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,833:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,838:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,844:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,844:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,856:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,856:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,870:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,870:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,886:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,886:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,886:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,886:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,904:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,904:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,904:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,920:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,920:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,920:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,936:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,936:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,936:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,936:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,953:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,953:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,953:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,953:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,970:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,970:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,970:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,970:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,987:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,987:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:29,987:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:29,987:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,003:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,003:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,003:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,003:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,020:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,020:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,020:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,020:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,036:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,036:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,036:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,036:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,053:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,053:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,053:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,053:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,070:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,070:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,070:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,070:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,070:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,085:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,087:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,087:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,087:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,103:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,103:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,103:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,103:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,103:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,120:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,120:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,120:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,120:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,136:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,137:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,137:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,137:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,137:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,137:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,153:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,155:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,157:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,157:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,157:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,157:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,169:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,170:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,173:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,173:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,173:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,173:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,186:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,188:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,190:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,191:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,194:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,194:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,194:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,194:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,204:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,205:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,207:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,208:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,210:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,211:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,214:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,215:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,215:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,223:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,226:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,227:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,229:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,230:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,232:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,233:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,236:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,237:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,239:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,240:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,242:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,243:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,243:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,243:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,243:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,252:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,254:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,255:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,257:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,258:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,260:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,261:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,263:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,264:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,266:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,267:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,269:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,269:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,271:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,272:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,274:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,275:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,277:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,277:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,277:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,277:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,287:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,288:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,289:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,290:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,292:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,293:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,294:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,295:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,297:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,298:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,300:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,301:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,302:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,303:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,304:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,305:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,307:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,307:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,309:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,310:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,311:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,312:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,313:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,314:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,315:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,316:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,317:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,318:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,319:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,321:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,321:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,321:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,321:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,321:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,321:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,321:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,321:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,321:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,321:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,336:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,337:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,338:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,339:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,340:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,341:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,342:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,343:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,344:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,345:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,346:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,347:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,347:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,348:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,349:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,350:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,351:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,352:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,353:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,354:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,355:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,356:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,357:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,358:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,359:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,360:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,361:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,362:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,362:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,363:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,364:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,365:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,366:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,367:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,367:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,368:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,369:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,370:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,371:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,372:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,372:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,374:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,374:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,375:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,376:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,377:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,378:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,379:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,379:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,379:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,386:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,388:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,389:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,390:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,391:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,392:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,393:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,394:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,395:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,411:INFO:Lee: Running sampling via ('Lee', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'rejection_level': 0.5, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Lee'}")
# 2024-08-23 12:35:30,412:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:35:30,415:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-23 12:35:30,416:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,449:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,453:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,482:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,489:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,515:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,517:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,539:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,541:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,562:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,564:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,584:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,586:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,603:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,603:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,630:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,631:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,648:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,648:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,672:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,674:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,690:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,690:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,706:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,706:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,720:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,720:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,736:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,736:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,771:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,771:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,787:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,787:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,803:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,803:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,819:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,819:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,836:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,836:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,852:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,852:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,869:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,869:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,886:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,886:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,903:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,903:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,920:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,920:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,937:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,937:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,953:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,953:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,969:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,969:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:30,986:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:30,986:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,002:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,002:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,019:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,019:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,036:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,036:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,052:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,052:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,068:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,070:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,070:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,070:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,086:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,086:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,105:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,105:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,119:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,119:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,135:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,135:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,154:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,156:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,160:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,168:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,175:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,175:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,190:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,190:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,202:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,204:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,208:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,208:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,223:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,226:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,226:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,237:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,245:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,245:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,258:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,260:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,266:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,269:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,280:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,281:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,287:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,287:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,302:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,304:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,311:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,311:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,323:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,325:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,331:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,332:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,341:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,343:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,350:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,351:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,355:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,355:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,369:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,370:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,378:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,378:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,390:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,392:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,398:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,399:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,404:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,404:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,404:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,418:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,424:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,426:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,426:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,435:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,441:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,442:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,448:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,449:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,453:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,453:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,453:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,453:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,472:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,474:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,479:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,481:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,489:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,491:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,497:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,498:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,503:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,504:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,509:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,510:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,513:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,521:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,526:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,528:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,533:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,534:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,539:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,540:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,545:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,545:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,552:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,553:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,557:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,558:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,562:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,563:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,567:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,568:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,572:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,573:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,578:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,578:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,587:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,589:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,593:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,594:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,598:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,599:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,603:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,604:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,607:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,608:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,612:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,613:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,619:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,622:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,625:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,626:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,630:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,631:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,634:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,635:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,638:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,639:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,642:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,643:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,646:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,647:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,650:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,651:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,654:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,655:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,655:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,655:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,655:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,655:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,670:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,671:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,675:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,676:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,679:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,680:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,683:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,684:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,687:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,688:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,691:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,692:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,695:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,696:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,698:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,699:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,701:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,702:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,704:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,704:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,704:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:31,704:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:31,704:INFO:Lee: simplex sampling with n_dim 2
# ...
# 2024-08-23 12:35:34,424:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,425:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,427:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,428:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,430:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,431:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,433:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,433:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,433:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,433:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,433:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,433:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,433:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,433:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,450:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,450:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,450:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,450:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,450:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,450:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,450:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,450:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,466:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,467:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,467:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,467:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,467:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,467:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,467:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,467:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,467:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,483:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,483:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,483:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,483:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,483:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,483:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,483:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,483:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,483:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,500:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,500:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,500:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,500:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,500:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,500:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,500:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,500:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,500:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,500:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,500:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,517:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,517:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,517:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,517:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,517:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,517:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,517:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,517:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,517:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,533:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,534:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,535:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,535:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,535:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,535:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,535:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,535:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,535:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,535:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,535:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,550:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,550:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,550:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,550:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,550:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,550:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,550:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,550:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,550:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,550:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,565:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,567:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,567:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,567:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,567:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,567:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,567:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,567:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,567:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,567:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,567:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,583:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,584:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,585:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,586:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,588:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,589:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,591:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,593:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,594:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,596:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,597:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,598:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,601:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,602:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,603:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,604:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,606:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,607:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,608:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,609:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,610:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,611:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,612:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,613:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,616:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,617:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,619:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,620:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,622:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,623:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,625:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,626:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,628:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,630:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,631:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,633:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,635:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,636:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,638:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,639:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,641:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,642:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,644:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,645:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,647:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,648:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,649:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,649:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,649:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,649:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,649:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,649:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,649:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,649:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,649:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,649:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,649:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,665:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,666:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,667:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,669:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,670:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,671:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,672:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,673:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,674:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,675:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,676:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,677:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,678:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,679:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,680:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,682:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,683:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,684:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,685:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,685:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,686:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,687:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,688:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,689:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,690:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,691:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,692:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,693:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,694:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,695:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,695:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,697:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,698:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,700:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,701:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,703:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,705:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,706:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,708:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,709:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,710:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,712:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,713:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,714:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,714:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,715:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,716:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,717:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,718:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,719:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,719:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,721:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,723:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-23 12:35:34,723:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-23 12:35:34,723:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
#   0%|          | 0/13284 [00:00<?, ?it/s]
#   0%|          | 0/13286 [00:00<?, ?it/s]
#   0%|          | 0/13296 [00:00<?, ?it/s]
#   0%|          | 0/13294 [00:00<?, ?it/s]
#   0%|          | 0/13280 [00:00<?, ?it/s]

# %%
summary_performace_for_all_oversampling_algorithms_all_folds_list=np.array([[[round(i,3) for i in summary_performace_for_all_oversampling_algorithms_all_folds[oversampler_index][key]] for key in summary_performace_for_all_oversampling_algorithms_all_folds[0].keys()] for oversampler_index in range(len(oversampler_name_list))])

# %%
oversamplers_result_summary_list=[]
for i in range(summary_performace_for_all_oversampling_algorithms_all_folds_list.shape[0]):
  performance_results_summary_list=[]
  for j in range(summary_performace_for_all_oversampling_algorithms_all_folds_list.shape[1]):
    performance_results_summary_list.append(str(summary_performace_for_all_oversampling_algorithms_all_folds_list[i][j][0])+"\u00B1"+str(summary_performace_for_all_oversampling_algorithms_all_folds_list[i][j][1]))
  oversamplers_result_summary_list.append(performance_results_summary_list)
oversamplers_result_summary_list=np.array(oversamplers_result_summary_list)

# %%
performance_results_summary_list
# Out:
# ['0.778±0.087', '0.576±0.074', '0.778±0.087', '0.778±0.087', '0.016±0.016']

# %%
oversamplers_result_summary_list
# Out:
# array([['0.805±0.008', '0.782±0.103', '0.805±0.008', '0.805±0.008',
#         '0.044±0.025'],
#        ['0.811±0.009', '0.775±0.092', '0.811±0.009', '0.811±0.009',
#         '0.043±0.022'],
#        ['0.8±0.01', '0.78±0.102', '0.8±0.01', '0.8±0.01', '0.042±0.024'],
#        ['0.891±0.057', '0.672±0.143', '0.891±0.057', '0.891±0.057',
#         '0.042±0.035'],
#        ['0.778±0.087', '0.576±0.074', '0.778±0.087', '0.778±0.087',
#         '0.016±0.016']], dtype='<U11')

# %%
df=pd.DataFrame(oversamplers_result_summary_list,columns=perfromance_measures,index=oversampler_name_list)

# %%
df
# Out:
#                         accuracy balanced accuracy       g-mean     f1-score  \
# SMOTE                0.805±0.008       0.782±0.103  0.805±0.008  0.805±0.008
# polynome_fit_SMOTE   0.811±0.009       0.775±0.092  0.811±0.009  0.811±0.009
# ProWSyn                 0.8±0.01        0.78±0.102     0.8±0.01     0.8±0.01
# Lee                  0.891±0.057       0.672±0.143  0.891±0.057  0.891±0.057
# Metropolis_hastings  0.778±0.087       0.576±0.074  0.778±0.087  0.778±0.087
#
#                      cohen_kappa
# SMOTE                0.044±0.025
# polynome_fit_SMOTE   0.043±0.022
# ProWSyn              0.042±0.024
# Lee                  0.042±0.035
# Metropolis_hastings  0.016±0.016

# %%
with pd.ExcelWriter('logistic_regression_clf_result_for_d5.xlsx') as excel_writer:
  df.to_excel(excel_writer,sheet_name='sheet_1')

# %%
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import f1_score
from imblearn.metrics import geometric_mean_score
from sklearn.metrics import cohen_kappa_score
from imblearn.over_sampling import SMOTE
from collections import Counter

# %%
with open('mammography_data.txt') as f:
  lines = [line.rstrip('\n')for line in f]

# %%
data_list=[]
for i in range(len(lines)):
    l= lines[i].split(',')
    a=[float(i) for i in l[:-1]]
    data_list.append(a)
data= np.array(data_list)

# %%
data.shape
# Out:
# (11183, 6)

# %%
labels_string=[]
for i in range(len(lines)):
  labels_string.append(lines[i].split(',')[-1])

# %%
labels=[]
for i in range(len(labels_string)):
  if labels_string[i]==np.unique(labels_string)[0]:
    labels.append(-1)
  else:
    labels.append(1)
labels=np.array(labels)

# %%
def get_folds(data,labels,k):
  np.random.seed(42)
  shuffle=np.random.permutation(len(data))
  data=data[shuffle]
  labels=labels[shuffle]

  block_length=int(len(data)/k)
  data_folds=[]
  label_folds=[]
  for i in range(k):
    if i==(k-1):
      data_fold=data[i*block_length:]
      data_folds.append(data_fold)
      label_fold=labels[i*block_length:]
      label_folds.append(label_fold)
    else:
      data_fold=data[i*block_length:block_length*(i+1)]
      data_folds.append(data_fold)
      label_fold=labels[i*block_length:block_length*(i+1)]
      label_folds.append(label_fold)
  return np.array(data_folds,dtype=object),np.array(label_folds,dtype=object)

# %%
def divide_data_into_k_folds(data,labels,k):
  data_folds_array,label_folds_array=get_folds(data,labels,k)
  all_data_folds_list=[]
  all_labels_folds_list=[]
  for i in range(k):
    data_fold_k=[np.concatenate(data_folds_array[np.where(np.array(list(range(k)))!=i)[0]]), data_folds_array[i]]
    all_data_folds_list.append(data_fold_k)

    label_fold_k=[np.concatenate(label_folds_array[np.where(np.array(list(range(k)))!=i)[0]]), label_folds_array[i]]
    all_labels_folds_list.append(label_fold_k)

  return all_data_folds_list, all_labels_folds_list

# %%
all_data_folds_list, all_labels_folds_list=divide_data_into_k_folds(data,labels,3)

# %%
X_train,X_test=all_data_folds_list[0][0],all_data_folds_list[0][1]

# %%
X_train.shape
# Out:
# (7456, 6)

# %%
y_train,y_test=all_labels_folds_list[0][0],all_labels_folds_list[0][1]

# %%
y_train.shape
# Out:
# (7456,)

# %%
np.unique(y_train, return_counts=True)
# Out:
# (array([-1,  1]), array([7280,  176], dtype=int64))

# %%
X_train_minority=[]
for i in np.where(y_train==1):
    a=X_train[i]
    X_train_minority.append(a)

# %%
X_train_minority_class=np.array(X_train_minority[0])

# %%
X_train_majority=[]
for i in np.where(y_train==-1):
    a=X_train[i]
    X_train_majority.append(a)

# %%
X_train_majority_class=np.array(X_train_majority[0])

# %%
def k(H,x,d):
  H_inv = np.linalg.inv(H)
  x_tras=np.matrix.transpose(x)
  h= np.linalg.det(H)
  m=np.matmul(x_tras,H_inv)
  m1=np.matmul(m,x)
  e=np.exp(-0.5*m1)
  n=2*(np.pi)**(-d/2)
  v=n*(h)**(-1/2)*(e)
  return v

# %%
def density_gen(X, X_minority):
    density_list=[]
    for j in range(len(X)):
        s=0
        for i in range(len(X_minority)):
            xi=X_minority[i]
            dif=X[j]-xi
            s=s+k(np.identity(X_minority.shape[1]), dif, X_minority.shape[1])
        density_list.append(s/len(X_minority))
    return np.array(density_list)

# %%
unique_labels,counts=np.unique(y_train, return_counts=True)

# %%
def metropolis_hastings(target_density, X_minority, size=100):
    np.random.seed(43)
    burnin_size = 10000
    size += burnin_size
    x0 =X_minority[np.random.choice(list(range(len(X_train_minority_class))),1)]
    xt = x0
    samples = []
    for i in tqdm(range(size)):
        xt_candidate = np.array([np.random.multivariate_normal(xt[0], 0.2*np.eye(X_minority.shape[1]))])
        accept_odds = (target_density(xt_candidate,X_minority))/(target_density(xt,X_minority))
        if np.random.uniform(0, 1) < accept_odds:
            xt = xt_candidate
        samples.append(xt)
    samples = np.array(samples[burnin_size:])
    samples = np.reshape(samples, [samples.shape[0], X_minority.shape[1]])
    return samples

# %%
# !pip install smote_variants
# Out:
# Collecting smote_variants
#   Using cached smote_variants-0.7.3-py3-none-any.whl.metadata (35 kB)
# Requirement already satisfied: numpy in c:\users\lenovo\anaconda3\lib\site-packages (from smote_variants) (1.26.4)
# Requirement already satisfied: scipy in c:\users\lenovo\anaconda3\lib\site-packages (from smote_variants) (1.13.1)
# Requirement already satisfied: scikit-learn in c:\users\lenovo\anaconda3\lib\site-packages (from smote_variants) (1.4.2)
# Requirement already satisfied: joblib in c:\users\lenovo\anaconda3\lib\site-packages (from smote_variants) (1.4.2)
# Collecting minisom (from smote_variants)
#   Using cached MiniSom-2.3.2.tar.gz (10 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting statistics (from smote_variants)
#   Using cached statistics-1.0.3.5.tar.gz (8.3 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting tensorflow (from smote_variants)
#   Using cached tensorflow-2.17.0-cp312-cp312-win_amd64.whl.metadata (3.2 kB)
# Collecting keras (from smote_variants)
#   Using cached keras-3.4.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: pandas in c:\users\lenovo\anaconda3\lib\site-packages (from smote_variants) (2.2.2)
# Collecting mkl (from smote_variants)
#   Using cached mkl-2024.2.0-py2.py3-none-win_amd64.whl.metadata (1.4 kB)
# Collecting metric-learn (from smote_variants)
#   Using cached metric_learn-0.7.0-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: seaborn in c:\users\lenovo\anaconda3\lib\site-packages (from smote_variants) (0.13.2)
# Collecting absl-py (from keras->smote_variants)
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: rich in c:\users\lenovo\anaconda3\lib\site-packages (from keras->smote_variants) (13.3.5)
# Collecting namex (from keras->smote_variants)
#   Using cached namex-0.0.8-py3-none-any.whl.metadata (246 bytes)
# Requirement already satisfied: h5py in c:\users\lenovo\anaconda3\lib\site-packages (from keras->smote_variants) (3.11.0)
# Collecting optree (from keras->smote_variants)
#   Using cached optree-0.12.1-cp312-cp312-win_amd64.whl.metadata (48 kB)
# Collecting ml-dtypes (from keras->smote_variants)
#   Using cached ml_dtypes-0.4.0-cp312-cp312-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: packaging in c:\users\lenovo\anaconda3\lib\site-packages (from keras->smote_variants) (23.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from scikit-learn->smote_variants) (2.2.0)
# Collecting intel-openmp>=2023 (from mkl->smote_variants)
#   Using cached intel_openmp-2024.2.0-py2.py3-none-win_amd64.whl.metadata (1.3 kB)
# Collecting tbb==2021.* (from mkl->smote_variants)
#   Using cached tbb-2021.13.0-py3-none-win_amd64.whl.metadata (1.1 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas->smote_variants) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas->smote_variants) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lenovo\anaconda3\lib\site-packages (from pandas->smote_variants) (2023.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\lenovo\anaconda3\lib\site-packages (from seaborn->smote_variants) (3.8.4)
# Requirement already satisfied: docutils>=0.3 in c:\users\lenovo\anaconda3\lib\site-packages (from statistics->smote_variants) (0.18.1)
# Collecting tensorflow-intel==2.17.0 (from tensorflow->smote_variants)
#   Using cached tensorflow_intel-2.17.0-cp312-cp312-win_amd64.whl.metadata (5.0 kB)
# Collecting astunparse>=1.6.0 (from tensorflow-intel==2.17.0->tensorflow->smote_variants)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow-intel==2.17.0->tensorflow->smote_variants)
#   Using cached flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow-intel==2.17.0->tensorflow->smote_variants)
#   Using cached gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow-intel==2.17.0->tensorflow->smote_variants)
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow-intel==2.17.0->tensorflow->smote_variants)
#   Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow-intel==2.17.0->tensorflow->smote_variants)
#   Using cached opt_einsum-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow->smote_variants) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow->smote_variants) (2.32.2)
# Requirement already satisfied: setuptools in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow->smote_variants) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow->smote_variants) (1.16.0)
# Collecting termcolor>=1.1.0 (from tensorflow-intel==2.17.0->tensorflow->smote_variants)
#   Using cached termcolor-2.4.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow->smote_variants) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow->smote_variants) (1.14.1)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow-intel==2.17.0->tensorflow->smote_variants)
#   Using cached grpcio-1.65.4-cp312-cp312-win_amd64.whl.metadata (3.4 kB)
# Collecting tensorboard<2.18,>=2.17 (from tensorflow-intel==2.17.0->tensorflow->smote_variants)
#   Using cached tensorboard-2.17.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting intel-cmplr-lib-ur==2024.2.0 (from intel-openmp>=2023->mkl->smote_variants)
#   Using cached intel_cmplr_lib_ur-2024.2.0-py2.py3-none-win_amd64.whl.metadata (1.3 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->smote_variants) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->smote_variants) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->smote_variants) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->smote_variants) (1.4.4)
# Requirement already satisfied: pillow>=8 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->smote_variants) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\lenovo\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->smote_variants) (3.0.9)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from rich->keras->smote_variants) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\lenovo\anaconda3\lib\site-packages (from rich->keras->smote_variants) (2.15.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\lenovo\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.17.0->tensorflow->smote_variants) (0.43.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras->smote_variants) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lenovo\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow->smote_variants) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow->smote_variants) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow->smote_variants) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow->smote_variants) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow->smote_variants) (3.4.1)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow->smote_variants)
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\lenovo\anaconda3\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow->smote_variants) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\lenovo\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow->smote_variants) (2.1.3)
# Using cached smote_variants-0.7.3-py3-none-any.whl (416 kB)
# Using cached keras-3.4.1-py3-none-any.whl (1.1 MB)
# Using cached metric_learn-0.7.0-py2.py3-none-any.whl (67 kB)
# Using cached mkl-2024.2.0-py2.py3-none-win_amd64.whl (161.5 MB)
# Using cached tbb-2021.13.0-py3-none-win_amd64.whl (286 kB)
# Using cached tensorflow-2.17.0-cp312-cp312-win_amd64.whl (2.0 kB)
# Using cached tensorflow_intel-2.17.0-cp312-cp312-win_amd64.whl (385.2 MB)
# Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
#    ---------------------------------------- 0.0/133.7 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/133.7 kB ? eta -:--:--
#    ----- --------------------------------- 20.5/133.7 kB 682.7 kB/s eta 0:00:01
#    ----- --------------------------------- 20.5/133.7 kB 682.7 kB/s eta 0:00:01
#    -------------- ------------------------ 51.2/133.7 kB 375.8 kB/s eta 0:00:01
#    -------------------------------- ----- 112.6/133.7 kB 595.3 kB/s eta 0:00:01
#    -------------------------------- ----- 112.6/133.7 kB 595.3 kB/s eta 0:00:01
#    -------------------------------------- 133.7/133.7 kB 527.6 kB/s eta 0:00:00
# Downloading intel_openmp-2024.2.0-py2.py3-none-win_amd64.whl (3.6 MB)
#    ---------------------------------------- 0.0/3.6 MB ? eta -:--:--
#     --------------------------------------- 0.1/3.6 MB 2.3 MB/s eta 0:00:02
#   Building wheel for statistics (setup.py): started
#   Building wheel for statistics (setup.py): finished with status 'done'
#   Created wheel for statistics: filename=statistics-1.0.3.5-py3-none-any.whl size=7450 sha256=bc7a964b6541c423eaa0bd0ee538416c2faa006fe3c957c8ad632fe7f5839c08
#   Stored in directory: c:\users\lenovo\appdata\local\pip\cache\wheels\10\9c\1a\0c68a89e4533a18e9f9902018b94ffc2481139818b67cbb05a
# Successfully built minisom statistics
# Installing collected packages: tbb, namex, minisom, libclang, intel-cmplr-lib-ur, flatbuffers, termcolor, tensorboard-data-server, statistics, optree, opt-einsum, ml-dtypes, intel-openmp, grpcio, google-pasta, gast, astunparse, absl-py, tensorboard, mkl, metric-learn, keras, tensorflow-intel, tensorflow, smote_variants
# Successfully installed absl-py-2.1.0 astunparse-1.6.3 flatbuffers-24.3.25 gast-0.6.0 google-pasta-0.2.0 grpcio-1.65.4 intel-cmplr-lib-ur-2024.2.0 intel-openmp-2024.2.0 keras-3.4.1 libclang-18.1.1 metric-learn-0.7.0 minisom-2.3.2 mkl-2024.2.0 ml-dtypes-0.4.0 namex-0.0.8 opt-einsum-3.3.0 optree-0.12.1 smote_variants-0.7.3 statistics-1.0.3.5 tbb-2021.13.0 tensorboard-2.17.0 tensorboard-data-server-0.7.2 tensorflow-2.17.0 tensorflow-intel-2.17.0 termcolor-2.4.0

# %%
import smote_variants as sv

oversampler_SMOTE=sv.SMOTE()
oversampler_polynome_fit = sv.polynom_fit_SMOTE_star()
oversampler_ProWSyn= sv.ProWSyn()
oversampler_SMOTE_IPF= sv.SMOTE_IPF()
oversampler_Lee= sv.Lee()

# %%
oversampler_object_list = [oversampler_SMOTE,oversampler_polynome_fit,oversampler_ProWSyn, oversampler_Lee, metropolis_hastings]

# %%
oversampler_name_list = ['SMOTE','polynome_fit_SMOTE','ProWSyn', 'Lee', 'Metropolis_hastings']

# %%
def get_imb_oversampling(X_train,y_train,X_test,y_test,oversampler_index,classifier,visualize=True):
  ## MH is in the end of the list oversampler_object_list
  if oversampler_index!=len(oversampler_object_list)-1:
    X_samp, y_samp = oversampler_object_list[oversampler_index].sample(X_train, y_train)

  else:
    X_train_minority=[]
    for i in np.where(y_train==1):
      a=X_train[i]
      X_train_minority.append(a)

    X_train_majority=[]
    for i in np.where(y_train==-1):
      a=X_train[i]
      X_train_majority.append(a)
    X_train_minority_class=np.array(X_train_minority[0])
    X_train_majority_class=np.array(X_train_majority[0])

    unique_labels,counts=np.unique(y_train, return_counts=True)

    synthetic_minority_data = metropolis_hastings(density_gen, X_train_minority_class, size=counts[0]-counts[1])
    balanced_minority=np.concatenate([X_train_minority_class, synthetic_minority_data])
    balanced_data=np.concatenate([X_train_majority_class,balanced_minority])
    balanced_labels_for_classification=np.concatenate([np.zeros(len(X_train_majority_class))-1,np.ones(len(balanced_minority))])
    X_samp=balanced_data
    y_samp=balanced_labels_for_classification

  classifier.fit(X_samp,y_samp)
  y_pred=classifier.predict(X_test)
  cm=confusion_matrix(y_test, y_pred)
  acc=accuracy_score(y_test, y_pred)
  b_acc=balanced_accuracy_score(y_test, y_pred)
  gm=geometric_mean_score(y_test, y_pred)
  f1=f1_score(y_test, y_pred)
  ck=cohen_kappa_score(y_test, y_pred)

  if visualize==True:
    scaler = StandardScaler()
    scaler.fit(X_samp)
    scaled_X_samp = scaler.transform(X_samp)
    pca = PCA(n_components =2)
    X_samp_pca=pca.fit_transform(scaled_X_samp)

    plt.figure(figsize=(8,6))
    color=["r","b"]
    color_counter=0
    for i in [-1,1]:
      plt.scatter(X_samp_pca[:,0][np.where(y_samp==i)],X_samp_pca[:,1][np.where(y_samp==i)], s=10, c=color[color_counter])
      color_counter=color_counter+1
    plt.legend(['Majority','Manority'],fontsize=10, loc='lower right')
    plt.xlabel("Principal Component 1",fontsize=12)
    plt.ylabel("Principlal Component 2 ",fontsize=12)
    plt.title("PCA plot of majority class + minority class using"+""+ oversampler_name_list[oversampler_index]+"technique",fontsize=14)


  return [cm, acc,b_acc,gm, f1, ck]

# %%
def calc_avg_performance(performance_index,results_all_folds):
  ## performance index takes the index of the performance measure foe which we want to average over folds
  ## results_all_folds are the results of a particular oversampler run over all folds recording all performance measures
  s=0
  for result in results_all_folds:
    s=s+result[performance_index]
  avg=s/len(results_all_folds)

  s=0
  for result in results_all_folds:
    s=s+(result[performance_index]-avg)**2
  std=np.sqrt(s/len(results_all_folds))
  return avg, std

# %%
clf = svm.SVC()

# %%
perfromance_measures=['accuracy','balanced accuracy','g-mean','f1-score','cohen_kappa']
def get_results_all_folds(oversampler_index,classifier, visualize=False, get_detailed_results=False):

  results_all_folds=[]
  for i in range(len(all_data_folds_list)):
    X_train,X_test=all_data_folds_list[i][0],all_data_folds_list[i][1]
    y_train,y_test=all_labels_folds_list[i][0],all_labels_folds_list[i][1]
    results_single_fold=get_imb_oversampling(X_train,y_train,X_test,y_test,oversampler_index,clf,visualize=visualize)
    results_all_folds.append(results_single_fold)

  performance_summary_oversampler_classifer={}
  for performance_index in range(1,6):
    avg_std=calc_avg_performance(performance_index,results_all_folds)
    performance_summary_oversampler_classifer[perfromance_measures[performance_index-1]]=avg_std

  if get_detailed_results==True:
    return results_all_folds, performance_summary_oversampler_classifer
  else:
    return performance_summary_oversampler_classifer

# %%
get_results_all_folds(0,clf)
# Out:
# 2024-08-05 12:47:23,127:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2024-08-05 12:47:23,127:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-05 12:47:23,144:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-05 12:47:23,152:INFO:SMOTE: simplex sampling with n_dim 2
# 2024-08-05 12:47:26,011:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2024-08-05 12:47:26,011:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-05 12:47:26,027:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-05 12:47:26,027:INFO:SMOTE: simplex sampling with n_dim 2
# 2024-08-05 12:47:28,283:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2024-08-05 12:47:28,283:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-05 12:47:28,283:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-05 12:47:28,283:INFO:SMOTE: simplex sampling with n_dim 2
# {'accuracy': (0.9505498747552074, 0.00635874680894716),
#  'balanced accuracy': (0.9044293285165907, 0.023151803572630837),
#  'g-mean': (0.9026160147840844, 0.02446423060143368),
#  'f1-score': (0.4465033948904917, 0.017956923633108256),
#  'cohen_kappa': (0.4268739053412833, 0.018592458233385463)}

# %%
summary_performace_for_all_oversampling_algorithms_all_folds=[]
for i in range(len(oversampler_object_list)):
  summary_performace_for_all_oversampling_algorithms_all_folds.append(get_results_all_folds(i,clf))
# Out:
# 2024-08-05 12:48:12,037:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2024-08-05 12:48:12,037:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-05 12:48:12,052:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-05 12:48:12,052:INFO:SMOTE: simplex sampling with n_dim 2
# 2024-08-05 12:48:14,964:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2024-08-05 12:48:14,964:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-05 12:48:14,964:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-05 12:48:14,964:INFO:SMOTE: simplex sampling with n_dim 2
# 2024-08-05 12:48:17,215:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'SMOTE'}")
# 2024-08-05 12:48:17,215:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-05 12:48:17,215:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-05 12:48:17,218:INFO:SMOTE: simplex sampling with n_dim 2
# 2024-08-05 12:48:19,397:INFO:polynom_fit_SMOTE_star: Running sampling via ('polynom_fit_SMOTE_star', "{'proportion': 1.0, 'topology': 'star', 'random_state': None, 'class_name': 'polynom_fit_SMOTE_star'}")
# 2024-08-05 12:48:19,397:INFO:polynom_fit_SMOTE: Running sampling via ('polynom_fit_SMOTE', "{'proportion': 1.0, 'topology': 'star', 'random_state': None, 'class_name': 'polynom_fit_SMOTE'}")
# 2024-08-05 12:48:20,777:INFO:polynom_fit_SMOTE_star: Running sampling via ('polynom_fit_SMOTE_star', "{'proportion': 1.0, 'topology': 'star', 'random_state': None, 'class_name': 'polynom_fit_SMOTE_star'}")
# 2024-08-05 12:48:20,777:INFO:polynom_fit_SMOTE: Running sampling via ('polynom_fit_SMOTE', "{'proportion': 1.0, 'topology': 'star', 'random_state': None, 'class_name': 'polynom_fit_SMOTE'}")
# 2024-08-05 12:48:21,978:INFO:polynom_fit_SMOTE_star: Running sampling via ('polynom_fit_SMOTE_star', "{'proportion': 1.0, 'topology': 'star', 'random_state': None, 'class_name': 'polynom_fit_SMOTE_star'}")
# 2024-08-05 12:48:21,978:INFO:polynom_fit_SMOTE: Running sampling via ('polynom_fit_SMOTE', "{'proportion': 1.0, 'topology': 'star', 'random_state': None, 'class_name': 'polynom_fit_SMOTE'}")
# 2024-08-05 12:48:23,159:INFO:ProWSyn: Running sampling via ('ProWSyn', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'L': 5, 'theta': 1.0, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'ProWSyn'}")
# 2024-08-05 12:48:23,159:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-05 12:48:23,166:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-05 12:48:23,177:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-05 12:48:23,182:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-05 12:48:23,185:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-05 12:48:23,185:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-05 12:48:23,194:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-05 12:48:23,194:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-05 12:48:23,392:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-05 12:48:23,394:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-05 12:48:23,426:INFO:ProWSyn: simplex sampling with n_dim 2
# 2024-08-05 12:48:23,429:INFO:ProWSyn: simplex sampling with n_dim 2
# 2024-08-05 12:48:23,437:INFO:ProWSyn: simplex sampling with n_dim 2
# 2024-08-05 12:48:23,437:INFO:ProWSyn: simplex sampling with n_dim 2
# 2024-08-05 12:48:23,437:INFO:ProWSyn: The simplex order was updated from 2 to 1
# 2024-08-05 12:48:23,437:INFO:ProWSyn: simplex sampling with n_dim 1
# 2024-08-05 12:48:26,044:INFO:ProWSyn: Running sampling via ('ProWSyn', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params':
 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Lee'}")
# 2024-08-05 12:48:31,481:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-05 12:48:31,489:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-05 12:48:31,489:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-05 12:48:31,489:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-05 12:48:31,489:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-05 12:48:31,553:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-05 12:48:31,553:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-05 12:48:31,570:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-05 12:48:31,570:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-05 12:48:31,570:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-05 12:48:31,581:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-05 12:48:31,581:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-05 12:48:31,585:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-05 12:48:31,588:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-05 12:48:31,588:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-05 12:48:31,588:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-05 12:48:31,588:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-05 12:48:32,619:INFO:Lee: Running sampling via ('Lee', "{'proportion': 1.0, 'n_neighbors': 5, 'nn_params': {}, 'rejection_level': 0.5, 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Lee'}")
# 2024-08-05 12:48:32,619:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-05 12:48:32,634:INFO:NearestNeighborsWithMetricTensor: NN fitting with metric minkowski
# 2024-08-05 12:48:32,639:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-05 12:48:32,641:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-05 12:48:32,641:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-05 12:48:32,707:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-05 12:48:32,707:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-05 12:48:32,731:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-05 12:48:32,734:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-05 12:48:32,739:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-05 12:48:32,743:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-05 12:48:32,751:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-05 12:48:32,751:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-05 12:48:32,751:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-05 12:48:32,751:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
# 2024-08-05 12:48:32,751:INFO:Lee: simplex sampling with n_dim 2
# 2024-08-05 12:48:32,759:INFO:NearestNeighborsWithMetricTensor: kneighbors query minkowski
#   0%|          | 0/17104 [00:00<?, ?it/s]

# %%
summary_performace_for_all_oversampling_algorithms_all_folds_list=np.array([[[round(i,3) for i in summary_performace_for_all_oversampling_algorithms_all_folds[oversampler_index][key]] for key in summary_performace_for_all_oversampling_algorithms_all_folds[0].keys()] for oversampler_index in range(len(oversampler_name_list))])

# %%
oversamplers_result_summary_list=[]
for i in range(summary_performace_for_all_oversampling_algorithms_all_folds_list.shape[0]):
  performance_results_summary_list=[]
  for j in range(summary_performace_for_all_oversampling_algorithms_all_folds_list.shape[1]):
    performance_results_summary_list.append(str(summary_performace_for_all_oversampling_algorithms_all_folds_list[i][j][0])+"\u00B1"+str(summary_performace_for_all_oversampling_algorithms_all_folds_list[i][j][1]))
  oversamplers_result_summary_list.append(performance_results_summary_list)
oversamplers_result_summary_list=np.array(oversamplers_result_summary_list)

# %%
performance_results_summary_list

# %%
oversamplers_result_summary_list

# %%
df=pd.DataFrame(oversamplers_result_summary_list,columns=perfromance_measures,index=oversampler_name_list)

# %%
df

# %%
with pd.ExcelWriter('_clf_result.xlsx') as excel_writer:
  df.to_excel(excel_writer,sheet_name='sheet_1')
